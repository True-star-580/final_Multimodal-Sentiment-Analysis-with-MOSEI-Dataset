# %%
# IMPORTANT: SOME KAGGLE DATA SOURCES ARE PRIVATE
# RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES.
import kagglehub
kagglehub.login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://www.kaggle.com/static/images/site-logo.png\nalt=\'Kaggle…
# Kaggle credentials set.
# Kaggle credentials successfully validated.

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

msa_challenge_at_the_4th_pazhou_ai_competition_path = kagglehub.competition_download('msa-challenge-at-the-4th-pazhou-ai-competition')
paulnkamau_dataset_cmu_mosei_extracted_path = kagglehub.dataset_download('paulnkamau/dataset-cmu-mosei-extracted')
paulnkamau_dataset_ch_simsv2_reorganized_path = kagglehub.dataset_download('paulnkamau/dataset-ch-simsv2-reorganized')
paulnkamau_dataset_public_test_n_validation_msa_v_to_a_to_t_path = kagglehub.dataset_download('paulnkamau/dataset-public-test-n-validation-msa-v-to-a-to-t')
paulnkamau_dataset_msa_translations_complete_path = kagglehub.dataset_download('paulnkamau/dataset-msa-translations-complete')
paulnkamau_bert_mosei_path = kagglehub.dataset_download('paulnkamau/bert-mosei')
paulnkamau_notebookd03142330b_path = kagglehub.notebook_output_download('paulnkamau/notebookd03142330b')

print('Data source import complete.')
# Out:
# Downloading from https://www.kaggle.com/api/v1/competitions/data/download-all/msa-challenge-at-the-4th-pazhou-ai-competition...
# 100%|██████████| 24.7G/24.7G [02:57<00:00, 149MB/s]
# Extracting files...
# Downloading from https://www.kaggle.com/api/v1/datasets/download/paulnkamau/dataset-cmu-mosei-extracted?dataset_version_number=1...
# 100%|██████████| 278k/278k [00:00<00:00, 86.6MB/s]
# Extracting files...
# Downloading from https://www.kaggle.com/api/v1/datasets/download/paulnkamau/dataset-ch-simsv2-reorganized?dataset_version_number=1...
# 100%|██████████| 12.8G/12.8G [01:41<00:00, 135MB/s]
# Extracting files...
# Downloading from https://www.kaggle.com/api/v1/datasets/download/paulnkamau/dataset-public-test-n-validation-msa-v-to-a-to-t?dataset_version_number=1...
# 100%|██████████| 436M/436M [00:02<00:00, 170MB/s]
# Extracting files...
# Downloading from https://www.kaggle.com/api/v1/datasets/download/paulnkamau/dataset-msa-translations-complete?dataset_version_number=1...
# 100%|██████████| 9.90M/9.90M [00:00<00:00, 94.8MB/s]
# Extracting files...
# Downloading from https://www.kaggle.com/api/v1/datasets/download/paulnkamau/bert-mosei?dataset_version_number=1...
# 100%|██████████| 62.5M/62.5M [00:00<00:00, 130MB/s]
# Extracting files...
# Downloading from https://www.kaggle.com/api/v1/kernels/output/download/paulnkamau/notebookd03142330b?version_number=4...
# Extracting files...
# Data source import complete.

# %%
import os
import pandas as pd
import json

def preview_directory(path, name):
    print(f"--- Previewing {name} ({path}) ---")
    if not os.path.exists(path):
        print(f"Directory not found: {path}")
        return

    file_list = []
    for root, _, files in os.walk(path):
        for file in files:
            file_list.append(os.path.join(root, file))

    if not file_list:
        print("No files found in the directory.")
        return

    print(f"Total number of files: {len(file_list)}")
    print("First 5 files:")
    for i, file_path in enumerate(file_list[:5]):
        print(file_path)

    print("\nPreviews of text-based files:")
    previewed_count = 0
    for file_path in file_list:
        if file_path.lower().endswith(('.csv', '.json')):
            try:
                print(f"\n--- {file_path} ---")
                if file_path.lower().endswith('.csv'):
                    # Try reading with different encodings
                    try:
                        df = pd.read_csv(file_path, encoding='utf-8')
                    except UnicodeDecodeError:
                        try:
                            df = pd.read_csv(file_path, encoding='latin-1')
                        except Exception as e:
                            print(f"Could not read CSV with common encodings: {e}")
                            continue
                    display(df.head())
                elif file_path.lower().endswith('.json'):
                    with open(file_path, 'r', encoding='utf-8') as f:
                        try:
                            data = json.load(f)
                            # Print first few items or keys for preview
                            if isinstance(data, list):
                                display(data[:5])
                            elif isinstance(data, dict):
                                display(list(data.keys())[:5])
                            else:
                                print(str(data)[:500] + '...') # Print first 500 chars
                        except Exception as e:
                            print(f"Could not read or parse JSON: {e}")

                previewed_count += 1
                if previewed_count >= 3: # Limit text file previews
                    print("\nLimiting text file previews to the first 3 found.")
                    break
            except Exception as e:
                print(f"Error processing {file_path}: {e}")


preview_directory(msa_challenge_at_the_4th_pazhou_ai_competition_path, 'msa-challenge-at-the-4th-pazhou-ai-competition')
preview_directory(paulnkamau_dataset_cmu_mosei_extracted_path, 'paulnkamau/dataset-cmu-mosei-extracted')
preview_directory(paulnkamau_dataset_ch_simsv2_reorganized_path, 'paulnkamau/dataset-ch-simsv2-reorganized')
preview_directory(paulnkamau_dataset_public_test_n_validation_msa_v_to_a_to_t_path, 'paulnkamau/dataset-public-test-n-validation-msa-v-to-a-to-t')
preview_directory(paulnkamau_dataset_msa_translations_complete_path, 'paulnkamau/dataset-msa-translations-complete')
preview_directory(paulnkamau_bert_mosei_path, 'paulnkamau/bert-mosei')
preview_directory(paulnkamau_notebookd03142330b_path, 'paulnkamau/notebookd03142330b')
# Out:
# --- Previewing msa-challenge-at-the-4th-pazhou-ai-competition (/root/.cache/kagglehub/competitions/msa-challenge-at-the-4th-pazhou-ai-competition) ---
# Total number of files: 75384
# First 5 files:
# /root/.cache/kagglehub/competitions/msa-challenge-at-the-4th-pazhou-ai-competition/validation_real_labels.csv
# /root/.cache/kagglehub/competitions/msa-challenge-at-the-4th-pazhou-ai-competition/Validation_Data/Validation_Data/validate_video_158.mp4
# /root/.cache/kagglehub/competitions/msa-challenge-at-the-4th-pazhou-ai-competition/Validation_Data/Validation_Data/validate_video_401.mp4
# /root/.cache/kagglehub/competitions/msa-challenge-at-the-4th-pazhou-ai-competition/Validation_Data/Validation_Data/validate_video_327.mp4
# /root/.cache/kagglehub/competitions/msa-challenge-at-the-4th-pazhou-ai-competition/Validation_Data/Validation_Data/validate_video_316.mp4
#
# Previews of text-based files:
#
# --- /root/.cache/kagglehub/competitions/msa-challenge-at-the-4th-pazhou-ai-competition/validation_real_labels.csv ---
#                        ID Label
# 0  validate_video_001.mp4  WPOS
# 1  validate_video_002.mp4  WNEG
# 2  validate_video_003.mp4  SNEG
# 3  validate_video_004.mp4  WPOS
# 4  validate_video_005.mp4  SNEG
# --- /root/.cache/kagglehub/competitions/msa-challenge-at-the-4th-pazhou-ai-competition/CH-SIMSv2/ch-simsv2s/meta.csv ---
#      video_id clip_id                   text  label  label_T  label_A  \
# 0  video_0001    0001                我不想嫁给李茶   -1.0     -1.0     -1.0
# 1  video_0001    0002              你这是嫁入豪门啊！    1.0      1.0      0.8
# 2  video_0001    0003    我不想嫁入什么豪门，我们不就是豪门吗？   -1.0     -0.8     -1.0
# 3  video_0001    0004                有那么明显吗？   -1.0     -0.6     -1.0
# 4  video_0001    0005  我在这消费这么多钱，我低血糖吃块糖还不行了   -1.0     -1.0     -1.0
#
#    label_V annotation   mode
# 0     -1.0   Negative  train
# 1      1.0   Positive  train
# 2     -1.0   Negative   test
# 3     -1.0   Negative  train
# 4     -1.0   Negative  train
# --- /root/.cache/kagglehub/competitions/msa-challenge-at-the-4th-pazhou-ai-competition/CMU-MOSEI/cmumosei/labels/transcript_valid.json ---
# ['9f6A3ucYArQ_3',
#  'O_fTDhCtAhw_1',
#  'TM7cHOHfF70_7',
#  '122842_0',
#  'FOMXt3lStco_0']
# Limiting text file previews to the first 3 found.
# --- Previewing paulnkamau/dataset-cmu-mosei-extracted (/root/.cache/kagglehub/datasets/paulnkamau/dataset-cmu-mosei-extracted/versions/1) ---
# Total number of files: 1
# First 5 files:
# /root/.cache/kagglehub/datasets/paulnkamau/dataset-cmu-mosei-extracted/versions/1/CMU-MOSEI_Extracted_Files/meta.csv
#
# Previews of text-based files:
#
# --- /root/.cache/kagglehub/datasets/paulnkamau/dataset-cmu-mosei-extracted/versions/1/CMU-MOSEI_Extracted_Files/meta.csv ---
#               ID Label                                         Video_Path  \
# 0  5Fs_7A_V2kA_0  NEUT  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
# 1  5Fs_7A_V2kA_1  WPOS  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
# 2  5Fs_7A_V2kA_2  WPOS  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
# 3  5Fs_7A_V2kA_3  WPOS  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
# 4  5Fs_7A_V2kA_4  WPOS  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
#
#                                           Audio_Path  \
# 0  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
# 1  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
# 2  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
# 3  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
# 4  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
#
#                                   Transcription_Path  split
# 0  /kaggle/input/msa-challenge-at-the-4th-pazhou-...  train
# 1  /kaggle/input/msa-challenge-at-the-4th-pazhou-...  train
# 2  /kaggle/input/msa-challenge-at-the-4th-pazhou-...  train
# 3  /kaggle/input/msa-challenge-at-the-4th-pazhou-...  train
# 4  /kaggle/input/msa-challenge-at-the-4th-pazhou-...  train
# --- Previewing paulnkamau/dataset-ch-simsv2-reorganized (/root/.cache/kagglehub/datasets/paulnkamau/dataset-ch-simsv2-reorganized/versions/1) ---
# Total number of files: 13210
# First 5 files:
# /root/.cache/kagglehub/datasets/paulnkamau/dataset-ch-simsv2-reorganized/versions/1/CH-SIMSv2/processed_data.csv
# /root/.cache/kagglehub/datasets/paulnkamau/dataset-ch-simsv2-reorganized/versions/1/CH-SIMSv2/extracted_audio/aqgy5_0016_00008.wav
# /root/.cache/kagglehub/datasets/paulnkamau/dataset-ch-simsv2-reorganized/versions/1/CH-SIMSv2/extracted_audio/aqgy5_0016_00045.wav
# /root/.cache/kagglehub/datasets/paulnkamau/dataset-ch-simsv2-reorganized/versions/1/CH-SIMSv2/extracted_audio/video_0023_0041.wav
# /root/.cache/kagglehub/datasets/paulnkamau/dataset-ch-simsv2-reorganized/versions/1/CH-SIMSv2/extracted_audio/video_0046_0032.wav
#
# Previews of text-based files:
#
# --- /root/.cache/kagglehub/datasets/paulnkamau/dataset-ch-simsv2-reorganized/versions/1/CH-SIMSv2/processed_data.csv ---
#                 ID Label
# 0  video_0001_0001  SNEG
# 1  video_0001_0002  SPOS
# 2  video_0001_0003  SNEG
# 3  video_0001_0004  SNEG
# 4  video_0001_0005  SNEG
# --- Previewing paulnkamau/dataset-public-test-n-validation-msa-v-to-a-to-t (/root/.cache/kagglehub/datasets/paulnkamau/dataset-public-test-n-validation-msa-v-to-a-to-t/versions/1) ---
# Total number of files: 1602
# First 5 files:
# /root/.cache/kagglehub/datasets/paulnkamau/dataset-public-test-n-validation-msa-v-to-a-to-t/versions/1/dataset_info.json
# /root/.cache/kagglehub/datasets/paulnkamau/dataset-public-test-n-validation-msa-v-to-a-to-t/versions/1/processing_log.csv
# /root/.cache/kagglehub/datasets/paulnkamau/dataset-public-test-n-validation-msa-v-to-a-to-t/versions/1/extracted_audio/public_test/public_test_video_082.wav
# /root/.cache/kagglehub/datasets/paulnkamau/dataset-public-test-n-validation-msa-v-to-a-to-t/versions/1/extracted_audio/public_test/public_test_video_066.wav
# /root/.cache/kagglehub/datasets/paulnkamau/dataset-public-test-n-validation-msa-v-to-a-to-t/versions/1/extracted_audio/public_test/public_test_video_334.wav
#
# Previews of text-based files:
#
# --- /root/.cache/kagglehub/datasets/paulnkamau/dataset-public-test-n-validation-msa-v-to-a-to-t/versions/1/dataset_info.json ---
# ['processing_date',
#  'whisper_model',
#  'audio_format',
#  'datasets_processed',
#  'total_files']
# --- /root/.cache/kagglehub/datasets/paulnkamau/dataset-public-test-n-validation-msa-v-to-a-to-t/versions/1/processing_log.csv ---
#                         file      dataset  audio_extracted  transcribed  error
# 0  public_test_video_001.mp4  public_test             True         True    NaN
# 1  public_test_video_002.mp4  public_test             True         True    NaN
# 2  public_test_video_003.mp4  public_test             True         True    NaN
# 3  public_test_video_004.mp4  public_test             True         True    NaN
# 4  public_test_video_005.mp4  public_test             True         True    NaN
# --- Previewing paulnkamau/dataset-msa-translations-complete (/root/.cache/kagglehub/datasets/paulnkamau/dataset-msa-translations-complete/versions/1) ---
# Total number of files: 5209
# First 5 files:
# /root/.cache/kagglehub/datasets/paulnkamau/dataset-msa-translations-complete/versions/1/cmu_mosei_meta_translated.csv
# /root/.cache/kagglehub/datasets/paulnkamau/dataset-msa-translations-complete/versions/1/CH-SIMSv2_english/video_0025_0028.txt
# /root/.cache/kagglehub/datasets/paulnkamau/dataset-msa-translations-complete/versions/1/CH-SIMSv2_english/aqgy5_0031_00009.txt
# /root/.cache/kagglehub/datasets/paulnkamau/dataset-msa-translations-complete/versions/1/CH-SIMSv2_english/video_0002_0007.txt
# /root/.cache/kagglehub/datasets/paulnkamau/dataset-msa-translations-complete/versions/1/CH-SIMSv2_english/video_0045_0064.txt
#
# Previews of text-based files:
#
# --- /root/.cache/kagglehub/datasets/paulnkamau/dataset-msa-translations-complete/versions/1/cmu_mosei_meta_translated.csv ---
#               ID Label                                         Video_Path  \
# 0  5Fs_7A_V2kA_0  NEUT  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
# 1  5Fs_7A_V2kA_1  WPOS  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
# 2  5Fs_7A_V2kA_2  WPOS  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
# 3  5Fs_7A_V2kA_3  WPOS  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
# 4  5Fs_7A_V2kA_4  WPOS  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
#
#                                           Audio_Path  \
# 0  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
# 1  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
# 2  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
# 3  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
# 4  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
#
#                                   Transcription_Path  split  \
# 0  /kaggle/input/msa-challenge-at-the-4th-pazhou-...  train
# 1  /kaggle/input/msa-challenge-at-the-4th-pazhou-...  train
# 2  /kaggle/input/msa-challenge-at-the-4th-pazhou-...  train
# 3  /kaggle/input/msa-challenge-at-the-4th-pazhou-...  train
# 4  /kaggle/input/msa-challenge-at-the-4th-pazhou-...  train
#
#                                         chinese_text  \
# 0  <s>If you want to discuss about this exam or c...
# 1  <s>Afterwards I will share my personal experie...
# 2  <s>It also deals with the ability to Identify ...
# 3  <s>This exam is intended for individuals who p...
# 4  <s>But we must not underestimate the importanc...
#
#                                  english_translation
# 0  If you want to discuss this exam or certifying...
# 1  Afterwards I will share my personal experience...
# 2  It also deals with the institution where multi...
# 3  This article is intended for individuals who p...
# 4  But we must not understand the significance of...
# --- /root/.cache/kagglehub/datasets/paulnkamau/dataset-msa-translations-complete/versions/1/CMU_Mosei_English/cmu_mosei_meta_translated_complete.csv ---
#               ID Label                                         Video_Path  \
# 0  5Fs_7A_V2kA_0  NEUT  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
# 1  5Fs_7A_V2kA_1  WPOS  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
# 2  5Fs_7A_V2kA_2  WPOS  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
# 3  5Fs_7A_V2kA_3  WPOS  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
# 4  5Fs_7A_V2kA_4  WPOS  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
#
#                                           Audio_Path  \
# 0  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
# 1  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
# 2  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
# 3  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
# 4  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
#
#                                   Transcription_Path  split  \
# 0  /kaggle/input/msa-challenge-at-the-4th-pazhou-...  train
# 1  /kaggle/input/msa-challenge-at-the-4th-pazhou-...  train
# 2  /kaggle/input/msa-challenge-at-the-4th-pazhou-...  train
# 3  /kaggle/input/msa-challenge-at-the-4th-pazhou-...  train
# 4  /kaggle/input/msa-challenge-at-the-4th-pazhou-...  train
#
#                                         chinese_text  \
# 0  <s>If you want to discuss about this exam or c...
# 1  <s>Afterwards I will share my personal experie...
# 2  <s>It also deals with the ability to Identify ...
# 3  <s>This exam is intended for individuals who p...
# 4  <s>But we must not underestimate the importanc...
#
#                                  english_translation
# 0  If you want to discuss this exam or certifying...
# 1  Afterwards I will share my personal experience...
# 2  It also deals with the institution where multi...
# 3  This article is intended for individuals who p...
# 4  But we must not understand the significance of...
# --- /root/.cache/kagglehub/datasets/paulnkamau/dataset-msa-translations-complete/versions/1/CMU_Mosei_English/cmu_mosei_bilingual_en_zh.csv ---
#               ID                                 Transcription_Path  \
# 0  5Fs_7A_V2kA_0  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
# 1  5Fs_7A_V2kA_1  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
# 2  5Fs_7A_V2kA_2  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
# 3  5Fs_7A_V2kA_3  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
# 4  5Fs_7A_V2kA_4  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
#
#                                         english_text  \
# 0  If you want to discuss about this exam or cert...
# 1  Afterwards I will share my personal experience...
# 2  It also deals with the ability to Identify sce...
# 3  This exam is intended for individuals who plan...
# 4  But we must not underestimate the importance o...
#
#                                  chinese_translation  \
# 0  如果您想讨论这项考试或认证,请访问“验证coaching.com”,这是一个自由和公开的认证...
# 1  之后我将分享我的个人经验, 如何减少微软MB2-707考试失败的机会, 考试内容是“微软动态...
# 2  它还涉及在设计移动表格时确定多种形式有用的情景、具体说明形式顺序、为形式指定角色和说明考虑的能力。
# 3  该考试的对象为计划定制和配置微软动态2015 CRM 2015的个人,对象通常包括执行顾问、...
# 4                                但是,我们决不能低估实践考试的重要性。
#
#                                  correction_applied  \
# 0  Original text is English - no translation needed
# 1  Original text is English - no translation needed
# 2  Original text is English - no translation needed
# 3  Original text is English - no translation needed
# 4  Original text is English - no translation needed
#
#                                     original_chinese  \
# 0  <s>If you want to discuss about this exam or c...
# 1  <s>Afterwards I will share my personal experie...
# 2  <s>It also deals with the ability to Identify ...
# 3  <s>This exam is intended for individuals who p...
# 4  <s>But we must not underestimate the importanc...
#
#                                     original_english Label  \
# 0  If you want to discuss this exam or certifying...  NEUT
# 1  Afterwards I will share my personal experience...  WPOS
# 2  It also deals with the institution where multi...  WPOS
# 3  This article is intended for individuals who p...  WPOS
# 4  But we must not understand the significance of...  WPOS
#
#                                           Video_Path  \
# 0  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
# 1  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
# 2  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
# 3  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
# 4  /kaggle/input/msa-challenge-at-the-4th-pazhou-...
#
#                                           Audio_Path  split
# 0  /kaggle/input/msa-challenge-at-the-4th-pazhou-...  train
# 1  /kaggle/input/msa-challenge-at-the-4th-pazhou-...  train
# 2  /kaggle/input/msa-challenge-at-the-4th-pazhou-...  train
# 3  /kaggle/input/msa-challenge-at-the-4th-pazhou-...  train
# 4  /kaggle/input/msa-challenge-at-the-4th-pazhou-...  train
# Limiting text file previews to the first 3 found.
# --- Previewing paulnkamau/bert-mosei (/root/.cache/kagglehub/datasets/paulnkamau/bert-mosei/versions/1) ---
# Total number of files: 1
# First 5 files:
# /root/.cache/kagglehub/datasets/paulnkamau/bert-mosei/versions/1/BERT_MOSEI.pkl
#
# Previews of text-based files:
# --- Previewing paulnkamau/notebookd03142330b (/root/.cache/kagglehub/notebooks/paulnkamau/notebookd03142330b/output/versions/4) ---
# Total number of files: 5
# First 5 files:
# /root/.cache/kagglehub/notebooks/paulnkamau/notebookd03142330b/output/versions/4/submission_detailed.csv
# /root/.cache/kagglehub/notebooks/paulnkamau/notebookd03142330b/output/versions/4/submission_alternative.csv
# /root/.cache/kagglehub/notebooks/paulnkamau/notebookd03142330b/output/versions/4/hybrid_submission_yoh.csv
# /root/.cache/kagglehub/notebooks/paulnkamau/notebookd03142330b/output/versions/4/submission.csv
# /root/.cache/kagglehub/notebooks/paulnkamau/notebookd03142330b/output/versions/4/final_submission.csv
#
# Previews of text-based files:
#
# --- /root/.cache/kagglehub/notebooks/paulnkamau/notebookd03142330b/output/versions/4/submission_detailed.csv ---
#                           ID Label matched_validation_video  similarity_score
# 0  public_test_video_001.mp4  WNEG   validate_video_002.mp4          0.093325
# 1  public_test_video_002.mp4  WPOS                UNMATCHED          0.000000
# 2  public_test_video_003.mp4  WPOS                UNMATCHED          0.000000
# 3  public_test_video_004.mp4  SPOS   validate_video_038.mp4          0.194228
# 4  public_test_video_005.mp4  WPOS                UNMATCHED          0.000000
# --- /root/.cache/kagglehub/notebooks/paulnkamau/notebookd03142330b/output/versions/4/submission_alternative.csv ---
#                           ID Label
# 0  public_test_video_142.mp4  SNEG
# 1  public_test_video_161.mp4  WNEG
# 2  public_test_video_218.mp4  NEUT
# 3  public_test_video_294.mp4  WPOS
# 4  public_test_video_007.mp4  SPOS
# --- /root/.cache/kagglehub/notebooks/paulnkamau/notebookd03142330b/output/versions/4/hybrid_submission_yoh.csv ---
#                           ID Label
# 0  public_test_video_001.mp4  WNEG
# 1  public_test_video_002.mp4  WNEG
# 2  public_test_video_003.mp4  SPOS
# 3  public_test_video_004.mp4  SPOS
# 4  public_test_video_005.mp4  SNEG
# Limiting text file previews to the first 3 found.

# %%
#

# %%
# !git clone https://github.com/True-star-580/nuu_multi-Multimodal-Sentiment-Analysis-with-MOSEI-Dataset.git
# %cd nuu_multi-Multimodal-Sentiment-Analysis-with-MOSEI-Dataset
# Out:
# Cloning into 'nuu_multi-Multimodal-Sentiment-Analysis-with-MOSEI-Dataset'...
# remote: Enumerating objects: 288, done.
# remote: Counting objects: 100% (288/288), done.
# remote: Compressing objects: 100% (147/147), done.
# remote: Total 288 (delta 128), reused 278 (delta 123), pack-reused 0 (from 0)
# Receiving objects: 100% (288/288), 21.98 MiB | 28.46 MiB/s, done.
# Resolving deltas: 100% (128/128), done.
# /content/nuu_multi-Multimodal-Sentiment-Analysis-with-MOSEI-Dataset

# %%
# !pip install -r requirements.txt -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 10.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 13.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 14.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 13.5 MB/s eta 0:00:00

# %%
# !python main.py
# Out:
# Streaming output truncated to the last 5000 lines.
#   0% 0/4 [00:00<?, ? Segments/s]
# Aligning ahG9c_uaf8s:   0% 0/4 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning ahcAFnY6iAY:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning ai7G98thPpk:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning aiJg0jtIHOM:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/8 [00:00<?, ? Segments/s]
# Aligning aiUq5xksJy0:   0% 0/8 [00:00<?, ? Segments/s]
#
#   0% 0/9 [00:00<?, ? Segments/s]
# Aligning ak7N0BqMluI:   0% 0/9 [00:00<?, ? Segments/s]
#
#   0% 0/6 [00:00<?, ? Segments/s]
# Aligning amem5EmRG3s:   0% 0/6 [00:00<?, ? Segments/s]
# Overall Progress:  66% 2172/3292 [00:58<00:17, 64.00 Computational Sequence Entries/s]
#   0% 0/5 [00:00<?, ? Segments/s]
# Aligning an_GzG40hcE:   0% 0/5 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning ap465Tlzf88:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/4 [00:00<?, ? Segments/s]
# Aligning aqmRPNfeOy8:   0% 0/4 [00:00<?, ? Segments/s]
#
#   0% 0/10 [00:00<?, ? Segments/s]
# Aligning asWraTfIqq0:   0% 0/10 [00:00<?, ? Segments/s]
#
#   0% 0/21 [00:00<?, ? Segments/s]
# Aligning assx_NKo-L8:   0% 0/21 [00:00<?, ? Segments/s]
#
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning atxoi7pB5TM:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/5 [00:00<?, ? Segments/s]
# Aligning auTpzciNgls:   0% 0/5 [00:00<?, ? Segments/s]
# Overall Progress:  66% 2179/3292 [00:58<00:18, 59.74 Computational Sequence Entries/s]
#   0% 0/8 [00:00<?, ? Segments/s]
# Aligning avW2m6VHTyg:   0% 0/8 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning axQ5CDRawO0:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/5 [00:00<?, ? Segments/s]
# Aligning b-FX9NOVQOM:   0% 0/5 [00:00<?, ? Segments/s]
#
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning b1Il3Nf6BrU:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/9 [00:00<?, ? Segments/s]
# Aligning b1LEcg6z66g:   0% 0/9 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning b7DK08bWU6c:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning b86B3hP8ARM:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/9 [00:00<?, ? Segments/s]
# Aligning b8xmgi4VV0M:   0% 0/9 [00:00<?, ? Segments/s]
# Overall Progress:  66% 2187/3292 [00:58<00:17, 62.93 Computational Sequence Entries/s]
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning b92iw0OAnI4:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning bAkUEnPoucg:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/22 [00:00<?, ? Segments/s]
# Aligning bBJ0BxmIocQ:   0% 0/22 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning bCBMKwafZKY:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning bCDfIJ12oqM:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/7 [00:00<?, ? Segments/s]
# Aligning bD0FqMn1KXw:   0% 0/7 [00:00<?, ? Segments/s]
#
#   0% 0/8 [00:00<?, ? Segments/s]
# Aligning bDwAuRFciJM:   0% 0/8 [00:00<?, ? Segments/s]
# Overall Progress:  67% 2194/3292 [00:59<00:18, 58.60 Computational Sequence Entries/s]
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning bEXCrGIOoWU:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning bI3DTH2yTbM:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/6 [00:00<?, ? Segments/s]
# Aligning bJI7-LnKPH4:   0% 0/6 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning bMuoPr5-Yt4:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/11 [00:00<?, ? Segments/s]
# Aligning bNQOeiAotbk:   0% 0/11 [00:00<?, ? Segments/s]
#
#   0% 0/5 [00:00<?, ? Segments/s]
# Aligning bNQkb4K5DX0:   0% 0/5 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning bQ8QteHvrEk:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/4 [00:00<?, ? Segments/s]
# Aligning bQcJVJcpgAs:   0% 0/4 [00:00<?, ? Segments/s]
# Overall Progress:  67% 2202/3292 [00:59<00:17, 63.06 Computational Sequence Entries/s]
#   0% 0/4 [00:00<?, ? Segments/s]
# Aligning bU6CgE_kMRY:   0% 0/4 [00:00<?, ? Segments/s]
#
#   0% 0/9 [00:00<?, ? Segments/s]
# Aligning bUFAN2TgPaU:   0% 0/9 [00:00<?, ? Segments/s]
#
#   0% 0/8 [00:00<?, ? Segments/s]
# Aligning bVhWpCvpSs4:   0% 0/8 [00:00<?, ? Segments/s]
#
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning bWmrrWQOVCM:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/8 [00:00<?, ? Segments/s]
# Aligning bWunvAd96zI:   0% 0/8 [00:00<?, ? Segments/s]
#
#   0% 0/5 [00:00<?, ? Segments/s]
# Aligning bYt4wybVLRQ:   0% 0/5 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning bZ2ytqPtyK4:   0% 0/1 [00:00<?, ? Segments/s]
# Overall Progress:  67% 2209/3292 [00:59<00:17, 62.16 Computational Sequence Entries/s]
#   0% 0/6 [00:00<?, ? Segments/s]
# Aligning b_SffSbPVJM:   0% 0/6 [00:00<?, ? Segments/s]
#
#   0% 0/12 [00:00<?, ? Segments/s]
# Aligning babuyKl7EAw:   0% 0/12 [00:00<?, ? Segments/s]
#
#   0% 0/5 [00:00<?, ? Segments/s]
# Aligning badtXoOJaf8:   0% 0/5 [00:00<?, ? Segments/s]
#
#   0% 0/5 [00:00<?, ? Segments/s]
# Aligning bcns0Gu66D8:   0% 0/5 [00:00<?, ? Segments/s]
#
#   0% 0/26 [00:00<?, ? Segments/s]
# Aligning bdFCD-3BCRg:   0% 0/26 [00:00<?, ? Segments/s]
#
#   0% 0/9 [00:00<?, ? Segments/s]
# Aligning bdtwQxwySN0:   0% 0/9 [00:00<?, ? Segments/s]
#
#   0% 0/5 [00:00<?, ? Segments/s]
# Aligning bfy28AlY-TQ:   0% 0/5 [00:00<?, ? Segments/s]
# Overall Progress:  67% 2216/3292 [00:59<00:21, 49.87 Computational Sequence Entries/s]
#   0% 0/4 [00:00<?, ? Segments/s]
# Aligning bge5PUG3G4A:   0% 0/4 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning bh4_Kd4hhd4:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning bhFK-xy76U4:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/6 [00:00<?, ? Segments/s]
# Aligning bhPB19tr-JY:   0% 0/6 [00:00<?, ? Segments/s]
#
#   0% 0/4 [00:00<?, ? Segments/s]
# Aligning bj9e8w4vNxo:   0% 0/4 [00:00<?, ? Segments/s]
#
#   0% 0/6 [00:00<?, ? Segments/s]
# Aligning bkP-BNW4oMg:   0% 0/6 [00:00<?, ? Segments/s]
#
#   0% 0/7 [00:00<?, ? Segments/s]
# Aligning bkX5FOX22Tw:   0% 0/7 [00:00<?, ? Segments/s]
#
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning bnzVR2ETQQ8:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/6 [00:00<?, ? Segments/s]
# Aligning bpvYdXVlgvc:   0% 0/6 [00:00<?, ? Segments/s]
# Overall Progress:  68% 2225/3292 [00:59<00:18, 58.30 Computational Sequence Entries/s]
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning bvycs3BXtx0:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/5 [00:00<?, ? Segments/s]
# Aligning bzPFUVGPS3c:   0% 0/5 [00:00<?, ? Segments/s]
#
#   0% 0/6 [00:00<?, ? Segments/s]
# Aligning c1a1y9ytHH0:   0% 0/6 [00:00<?, ? Segments/s]
#
#   0% 0/5 [00:00<?, ? Segments/s]
# Aligning c5-L8vC6_sk:   0% 0/5 [00:00<?, ? Segments/s]
#
#   0% 0/7 [00:00<?, ? Segments/s]
# Aligning c5AJbOd794U:   0% 0/7 [00:00<?, ? Segments/s]
#
#   0% 0/20 [00:00<?, ? Segments/s]
# Aligning c5VEvmutmVg:   0% 0/20 [00:00<?, ? Segments/s]
#
#   0% 0/4 [00:00<?, ? Segments/s]
# Aligning c5cB7AfVgcE:   0% 0/4 [00:00<?, ? Segments/s]
# Overall Progress:  68% 2232/3292 [00:59<00:19, 54.64 Computational Sequence Entries/s]
#   0% 0/7 [00:00<?, ? Segments/s]
# Aligning c5zxqITn3ZM:   0% 0/7 [00:00<?, ? Segments/s]
#
#   0% 0/8 [00:00<?, ? Segments/s]
# Aligning c6wuh0NRG1s:   0% 0/8 [00:00<?, ? Segments/s]
#
#   0% 0/8 [00:00<?, ? Segments/s]
# Aligning c7xUcM68IFE:   0% 0/8 [00:00<?, ? Segments/s]
#
#   0% 0/9 [00:00<?, ? Segments/s]
# Aligning c805Td8A_Ek:   0% 0/9 [00:00<?, ? Segments/s]
#
#   0% 0/5 [00:00<?, ? Segments/s]
# Aligning c9hE1ghElrM:   0% 0/5 [00:00<?, ? Segments/s]
#
#   0% 0/7 [00:00<?, ? Segments/s]
# Aligning c9jD33baJ60:   0% 0/7 [00:00<?, ? Segments/s]
# Overall Progress:  68% 2238/3292 [00:59<00:21, 49.15 Computational Sequence Entries/s]
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning cAA2mONG98w:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/5 [00:00<?, ? Segments/s]
# Aligning cEXJ2zFbC9I:   0% 0/5 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning cHBRDdSXLtU:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning cHrOisasWLU:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning cKUPgzZu-Fk:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning cKldvZeyRDA:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning cKxNJY7sA8s:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning cM1Zuji24dI:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning cMUS4nhcKCQ:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning cMsTvqU_-rc:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/16 [00:00<?, ? Segments/s]
# Aligning cOcNe3L4VAg:   0% 0/16 [00:00<?, ? Segments/s]
# Overall Progress:  68% 2249/3292 [00:59<00:17, 60.19 Computational Sequence Entries/s]
#   0% 0/4 [00:00<?, ? Segments/s]
# Aligning cRFiXLzcCOA:   0% 0/4 [00:00<?, ? Segments/s]
#
#   0% 0/10 [00:00<?, ? Segments/s]
# Aligning cR_KQlNhoNE:   0% 0/10 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning cS3BDGNDu_8:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning cSrM5mHACmA:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning cSraseCDilY:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/6 [00:00<?, ? Segments/s]
# Aligning cUm0TN3vXRc:   0% 0/6 [00:00<?, ? Segments/s]
#
#   0% 0/38 [00:00<?, ? Segments/s]
# Aligning cW-aX4dPVfk:   0% 0/38 [00:00<?, ? Segments/s]
# Aligning cW-aX4dPVfk:  82% 31/38 [00:00<00:00, 303.43 Segments/s]
# Overall Progress:  69% 2256/3292 [01:00<00:20, 50.23 Computational Sequence Entries/s]
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning cWN1bibicHc:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning cX8FScpsfLE:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning cXu56oK462o:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning cY8DcaHXNNs:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/4 [00:00<?, ? Segments/s]
# Aligning cZDAM6NjBzE:   0% 0/4 [00:00<?, ? Segments/s]
#
#   0% 0/27 [00:00<?, ? Segments/s]
# Aligning cZVM4svwE90:   0% 0/27 [00:00<?, ? Segments/s]
# Overall Progress:  69% 2262/3292 [01:00<00:20, 49.86 Computational Sequence Entries/s]
#   0% 0/11 [00:00<?, ? Segments/s]
# Aligning c_FJuhSte8Q:   0% 0/11 [00:00<?, ? Segments/s]
#
#   0% 0/11 [00:00<?, ? Segments/s]
# Aligning caLWajc18Y4:   0% 0/11 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning ce1ObTPlI38:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/6 [00:00<?, ? Segments/s]
# Aligning cfX_iuhCbRY:   0% 0/6 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning cia8OM3Oe7Q:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/7 [00:00<?, ? Segments/s]
# Aligning cjgq9d8Zn9g:   0% 0/7 [00:00<?, ? Segments/s]
# Overall Progress:  69% 2268/3292 [01:00<00:19, 51.85 Computational Sequence Entries/s]
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning cl1DNRGX578:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning cmJW6mkspkI:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/7 [00:00<?, ? Segments/s]
# Aligning cml9rShionM:   0% 0/7 [00:00<?, ? Segments/s]
#
#   0% 0/9 [00:00<?, ? Segments/s]
# Aligning cn0WZ8-0Z1Y:   0% 0/9 [00:00<?, ? Segments/s]
#
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning cnllFPRyBFs:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning ctAZf4sMBUQ:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/8 [00:00<?, ? Segments/s]
# Aligning ctMCSUT2LlQ:   0% 0/8 [00:00<?, ? Segments/s]
# Overall Progress:  69% 2275/3292 [01:00<00:18, 55.54 Computational Sequence Entries/s]
#   0% 0/9 [00:00<?, ? Segments/s]
# Aligning cuR-l2qCxBc:   0% 0/9 [00:00<?, ? Segments/s]
#
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning cyOSDKOxb1o:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning cyu1HhakSaQ:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/5 [00:00<?, ? Segments/s]
# Aligning d-Uw_uZyUys:   0% 0/5 [00:00<?, ? Segments/s]
#
#   0% 0/22 [00:00<?, ? Segments/s]
# Aligning d0QNH2vcDgU:   0% 0/22 [00:00<?, ? Segments/s]
#
#   0% 0/13 [00:00<?, ? Segments/s]
# Aligning d1CDP6sMuLA:   0% 0/13 [00:00<?, ? Segments/s]
# Overall Progress:  69% 2281/3292 [01:00<00:20, 49.12 Computational Sequence Entries/s]
#   0% 0/15 [00:00<?, ? Segments/s]
# Aligning d38u9n5GOLM:   0% 0/15 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning d3EeIRaMbbk:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/11 [00:00<?, ? Segments/s]
# Aligning d3I7Ug-_3L0:   0% 0/11 [00:00<?, ? Segments/s]
#
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning d7Dz34-cZ74:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/6 [00:00<?, ? Segments/s]
# Aligning d89Z_olwc2Y:   0% 0/6 [00:00<?, ? Segments/s]
#
#   0% 0/10 [00:00<?, ? Segments/s]
# Aligning d8BR6hsvzoY:   0% 0/10 [00:00<?, ? Segments/s]
# Overall Progress:  69% 2287/3292 [01:00<00:21, 47.80 Computational Sequence Entries/s]
#   0% 0/16 [00:00<?, ? Segments/s]
# Aligning d99mfGIenCo:   0% 0/16 [00:00<?, ? Segments/s]
#
#   0% 0/12 [00:00<?, ? Segments/s]
# Aligning dBWvtPeHpWM:   0% 0/12 [00:00<?, ? Segments/s]
#
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning dCDAcBR505Q:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/5 [00:00<?, ? Segments/s]
# Aligning dDFyJp_OkeA:   0% 0/5 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning dEBug0QYayY:   0% 0/1 [00:00<?, ? Segments/s]
# Overall Progress:  70% 2292/3292 [01:00<00:20, 47.94 Computational Sequence Entries/s]
#   0% 0/6 [00:00<?, ? Segments/s]
# Aligning dEDbm2ubVRQ:   0% 0/6 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning dEXSb0CfodU:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning dH0FmwvOzs0:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/4 [00:00<?, ? Segments/s]
# Aligning dHk--ExZbHs:   0% 0/4 [00:00<?, ? Segments/s]
#
#   0% 0/4 [00:00<?, ? Segments/s]
# Aligning dJ5MXl66-UQ:   0% 0/4 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning dLmtsRyRH4s:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning dLzsNc_hzkQ:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning dOSyvhYsfFo:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/4 [00:00<?, ? Segments/s]
# Aligning dQ56b0bqmc8:   0% 0/4 [00:00<?, ? Segments/s]
# Overall Progress:  70% 2301/3292 [01:01<00:17, 55.21 Computational Sequence Entries/s]
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning dR68gbeOWOc:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/7 [00:00<?, ? Segments/s]
# Aligning dSax_7klbfE:   0% 0/7 [00:00<?, ? Segments/s]
#
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning dTcz1am1eUw:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/6 [00:00<?, ? Segments/s]
# Aligning dWfgSGnd9zM:   0% 0/6 [00:00<?, ? Segments/s]
#
#   0% 0/7 [00:00<?, ? Segments/s]
# Aligning dXMAS2tIknw:   0% 0/7 [00:00<?, ? Segments/s]
#
#   0% 0/7 [00:00<?, ? Segments/s]
# Aligning dYgmvmFegkQ:   0% 0/7 [00:00<?, ? Segments/s]
# Overall Progress:  70% 2307/3292 [01:01<00:18, 54.31 Computational Sequence Entries/s]
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning dYyg91d7zjY:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning dZK01jhM27k:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning dZolFNqR-hA:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning damyXH7mBic:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning dbH51F5Zqi4:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning dbpGH5iP0GE:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning dcUlt6zk_S0:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning ddWHTdJz2O8:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning ddix4XuaUlY:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/9 [00:00<?, ? Segments/s]
# Aligning dlE05KC95uk:   0% 0/9 [00:00<?, ? Segments/s]
#
#   0% 0/9 [00:00<?, ? Segments/s]
# Aligning dqragS38hCk:   0% 0/9 [00:00<?, ? Segments/s]
# Overall Progress:  70% 2318/3292 [01:01<00:15, 63.72 Computational Sequence Entries/s]
#   0% 0/16 [00:00<?, ? Segments/s]
# Aligning dsob2MgUPpA:   0% 0/16 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning dt641WxonBI:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning dxsPkcG-Q30:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/10 [00:00<?, ? Segments/s]
# Aligning dyZdiWNflko:   0% 0/10 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning dzSv6GwfF-0:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning e-2QlzFeyNU:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning e0hYEr848TE:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/9 [00:00<?, ? Segments/s]
# Aligning e0ltF8zpEcw:   0% 0/9 [00:00<?, ? Segments/s]
#
#   0% 0/7 [00:00<?, ? Segments/s]
# Aligning e1E5W_ZefmY:   0% 0/7 [00:00<?, ? Segments/s]
# Overall Progress:  71% 2327/3292 [01:01<00:14, 67.83 Computational Sequence Entries/s]
#   0% 0/18 [00:00<?, ? Segments/s]
# Aligning e7_2U4lm6TE:   0% 0/18 [00:00<?, ? Segments/s]
#
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning eD5cScqaf6c:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/4 [00:00<?, ? Segments/s]
# Aligning eE8Qr9fOvVA:   0% 0/4 [00:00<?, ? Segments/s]
#
#   0% 0/12 [00:00<?, ? Segments/s]
# Aligning eFV7iFPYZB4:   0% 0/12 [00:00<?, ? Segments/s]
#
#   0% 0/7 [00:00<?, ? Segments/s]
# Aligning eJfT7-dDqzA:   0% 0/7 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning eJwZfdtlks8:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning eKQKEi2-0Ws:   0% 0/1 [00:00<?, ? Segments/s]
# Overall Progress:  71% 2334/3292 [01:01<00:16, 57.75 Computational Sequence Entries/s]
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning eKRWfaizBO0:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning eMa6gbD7id0:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning eOU_40p9RpA:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/5 [00:00<?, ? Segments/s]
# Aligning eOiC1kb17P4:   0% 0/5 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning ePiz4zU6crI:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/7 [00:00<?, ? Segments/s]
# Aligning ePtlUYCdrNM:   0% 0/7 [00:00<?, ? Segments/s]
#
#   0% 0/6 [00:00<?, ? Segments/s]
# Aligning eQc5uI7FKCU:   0% 0/6 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning eREud0qYR3s:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/8 [00:00<?, ? Segments/s]
# Aligning eSHOcLD5T58:   0% 0/8 [00:00<?, ? Segments/s]
# Overall Progress:  71% 2343/3292 [01:01<00:14, 65.02 Computational Sequence Entries/s]
#   0% 0/4 [00:00<?, ? Segments/s]
# Aligning eTCnM472-cQ:   0% 0/4 [00:00<?, ? Segments/s]
#
#   0% 0/14 [00:00<?, ? Segments/s]
# Aligning eTn2P4wmFr4:   0% 0/14 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning eUwbRLhV1vs:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/8 [00:00<?, ? Segments/s]
# Aligning eW1vgHE6FRM:   0% 0/8 [00:00<?, ? Segments/s]
#
#   0% 0/5 [00:00<?, ? Segments/s]
# Aligning eY64P27khzk:   0% 0/5 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning eYCiRWf2NHE:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/4 [00:00<?, ? Segments/s]
# Aligning eZVcshSUD3Q:   0% 0/4 [00:00<?, ? Segments/s]
# Overall Progress:  71% 2350/3292 [01:01<00:15, 60.64 Computational Sequence Entries/s]
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning eaXDCknxPrU:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/4 [00:00<?, ? Segments/s]
# Aligning eeN7l4R3nPc:   0% 0/4 [00:00<?, ? Segments/s]
#
#   0% 0/12 [00:00<?, ? Segments/s]
# Aligning efLrpnuLwyU:   0% 0/12 [00:00<?, ? Segments/s]
#
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning ehZrOdw6PhA:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning ejDe6hQWZOk:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning emtvrtk-jsU:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning eo8L7lCTjDQ:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/7 [00:00<?, ? Segments/s]
# Aligning ep3IasggD3k:   0% 0/7 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning erBIIKA6r5Y:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning erNDEjQeox8:   0% 0/2 [00:00<?, ? Segments/s]
# Overall Progress:  72% 2360/3292 [01:01<00:13, 69.86 Computational Sequence Entries/s]
#   0% 0/7 [00:00<?, ? Segments/s]
# Aligning esR-tOjT6KM:   0% 0/7 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning esnOE1LefKA:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/4 [00:00<?, ? Segments/s]
# Aligning etPDgRjrnJ8:   0% 0/4 [00:00<?, ? Segments/s]
#
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning evAswZ6m3hg:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning ewBrNsyY82Q:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning ex-dKshlXoY:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/4 [00:00<?, ? Segments/s]
# Aligning ey1lr8wFFDc:   0% 0/4 [00:00<?, ? Segments/s]
#
#   0% 0/4 [00:00<?, ? Segments/s]
# Aligning ezuWKsxPRSM:   0% 0/4 [00:00<?, ? Segments/s]
#
#   0% 0/5 [00:00<?, ? Segments/s]
# Aligning f-VdKweez2U:   0% 0/5 [00:00<?, ? Segments/s]
#
#   0% 0/6 [00:00<?, ? Segments/s]
# Aligning f-ZNjqLlrm4:   0% 0/6 [00:00<?, ? Segments/s]
# Overall Progress:  72% 2370/3292 [01:02<00:12, 73.74 Computational Sequence Entries/s]
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning f47bnEUrOvA:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/6 [00:00<?, ? Segments/s]
# Aligning f49boM5fb8U:   0% 0/6 [00:00<?, ? Segments/s]
#
#   0% 0/4 [00:00<?, ? Segments/s]
# Aligning f5k5cF80aUE:   0% 0/4 [00:00<?, ? Segments/s]
#
#   0% 0/11 [00:00<?, ? Segments/s]
# Aligning f6S2XNPIiFk:   0% 0/11 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning f8Puta8k8fU:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning fB816aeHRFk:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning fDYZINwIs_A:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning fEm9AdLNrjk:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning fGYbbP8RDLQ:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/4 [00:00<?, ? Segments/s]
# Aligning fI9KptYFZeg:   0% 0/4 [00:00<?, ? Segments/s]
# Overall Progress:  72% 2380/3292 [01:02<00:11, 80.49 Computational Sequence Entries/s]
#   0% 0/6 [00:00<?, ? Segments/s]
# Aligning fMUmdlzuc94:   0% 0/6 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning fOxg1NstCHA:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning fPsy1co_nuw:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/5 [00:00<?, ? Segments/s]
# Aligning fSOVk2cS-sY:   0% 0/5 [00:00<?, ? Segments/s]
#
#   0% 0/11 [00:00<?, ? Segments/s]
# Aligning fT6SrlsWV7M:   0% 0/11 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning fTKe7E_4OCQ:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/6 [00:00<?, ? Segments/s]
# Aligning fTNOAssiTYk:   0% 0/6 [00:00<?, ? Segments/s]
#
#   0% 0/4 [00:00<?, ? Segments/s]
# Aligning fU5AYkq0m9k:   0% 0/4 [00:00<?, ? Segments/s]
#
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning fVCDn6SdtVM:   0% 0/3 [00:00<?, ? Segments/s]
# Overall Progress:  73% 2389/3292 [01:02<00:11, 81.03 Computational Sequence Entries/s]
#   0% 0/8 [00:00<?, ? Segments/s]
# Aligning fW1pK2L6RgM:   0% 0/8 [00:00<?, ? Segments/s]
#
#   0% 0/8 [00:00<?, ? Segments/s]
# Aligning fWAKek8jA5M:   0% 0/8 [00:00<?, ? Segments/s]
#
#   0% 0/12 [00:00<?, ? Segments/s]
# Aligning fWOIAxzBQFY:   0% 0/12 [00:00<?, ? Segments/s]
#
#   0% 0/15 [00:00<?, ? Segments/s]
# Aligning f_ZJ7L14oYQ:   0% 0/15 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning faMq0C_wTpU:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning faUvT7zfsyk:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/16 [00:00<?, ? Segments/s]
# Aligning faXGVcVcVsE:   0% 0/16 [00:00<?, ? Segments/s]
#
#   0% 0/12 [00:00<?, ? Segments/s]
# Aligning fbHlBmq7Ipo:   0% 0/12 [00:00<?, ? Segments/s]
#
#   0% 0/5 [00:00<?, ? Segments/s]
# Aligning fbSxct2JcKU:   0% 0/5 [00:00<?, ? Segments/s]
# Overall Progress:  73% 2398/3292 [01:02<00:15, 58.46 Computational Sequence Entries/s]
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning fcxbB7ybUfs:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/4 [00:00<?, ? Segments/s]
# Aligning fdK_tsvBXJ8:   0% 0/4 [00:00<?, ? Segments/s]
#
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning fdc7iyzKvFQ:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning fe2CWCpdTF8:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning ffrJ91swyq0:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/4 [00:00<?, ? Segments/s]
# Aligning fhADeWE5VgU:   0% 0/4 [00:00<?, ? Segments/s]
#
#   0% 0/4 [00:00<?, ? Segments/s]
# Aligning fhY2vbnjuWY:   0% 0/4 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning fi7g4GoK-z4:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/12 [00:00<?, ? Segments/s]
# Aligning fiXZqpbRYKk:   0% 0/12 [00:00<?, ? Segments/s]
# Overall Progress:  73% 2407/3292 [01:02<00:14, 59.53 Computational Sequence Entries/s]
#   0% 0/7 [00:00<?, ? Segments/s]
# Aligning fjE2EZKgQm8:   0% 0/7 [00:00<?, ? Segments/s]
#
#   0% 0/8 [00:00<?, ? Segments/s]
# Aligning flBtk736di4:   0% 0/8 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning flGZteJUNYU:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/12 [00:00<?, ? Segments/s]
# Aligning flv4by3RYVk:   0% 0/12 [00:00<?, ? Segments/s]
#
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning fnFoRPqkQeo:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/7 [00:00<?, ? Segments/s]
# Aligning foXArPhK0xY:   0% 0/7 [00:00<?, ? Segments/s]
#
#   0% 0/4 [00:00<?, ? Segments/s]
# Aligning frCWtiam4tE:   0% 0/4 [00:00<?, ? Segments/s]
# Overall Progress:  73% 2414/3292 [01:02<00:14, 61.71 Computational Sequence Entries/s]
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning frNJdG0GkYw:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning fsBzpr4k3rY:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning fsd1qPLA3kY:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/13 [00:00<?, ? Segments/s]
# Aligning fz-MzQcOBwQ:   0% 0/13 [00:00<?, ? Segments/s]
#
#   0% 0/23 [00:00<?, ? Segments/s]
# Aligning fzuTEKwNS94:   0% 0/23 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning g6VJg6ycUk0:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/5 [00:00<?, ? Segments/s]
# Aligning g8Cl74tS3oY:   0% 0/5 [00:00<?, ? Segments/s]
# Overall Progress:  74% 2421/3292 [01:02<00:15, 55.30 Computational Sequence Entries/s]
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning g8NBNtY3cpU:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/9 [00:00<?, ? Segments/s]
# Aligning g99kISQbyuI:   0% 0/9 [00:00<?, ? Segments/s]
#
#   0% 0/6 [00:00<?, ? Segments/s]
# Aligning g9rNhtFG9aU:   0% 0/6 [00:00<?, ? Segments/s]
#
#   0% 0/5 [00:00<?, ? Segments/s]
# Aligning gAMbkJk6gnE:   0% 0/5 [00:00<?, ? Segments/s]
#
#   0% 0/6 [00:00<?, ? Segments/s]
# Aligning gC_wF3uKFW0:   0% 0/6 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning gE7kUqMqQ9g:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/32 [00:00<?, ? Segments/s]
# Aligning gEgcpVY8WK4:   0% 0/32 [00:00<?, ? Segments/s]
# Overall Progress:  74% 2428/3292 [01:03<00:16, 52.09 Computational Sequence Entries/s]
#   0% 0/6 [00:00<?, ? Segments/s]
# Aligning gFAOKuqpUq4:   0% 0/6 [00:00<?, ? Segments/s]
#
#   0% 0/4 [00:00<?, ? Segments/s]
# Aligning gJdSxPhf85M:   0% 0/4 [00:00<?, ? Segments/s]
#
#   0% 0/4 [00:00<?, ? Segments/s]
# Aligning gJjkCPO7iXg:   0% 0/4 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning gKojBrXHhUc:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/10 [00:00<?, ? Segments/s]
# Aligning gL8h7lOPv1Q:   0% 0/10 [00:00<?, ? Segments/s]
#
#   0% 0/12 [00:00<?, ? Segments/s]
# Aligning gLTxaEcx41E:   0% 0/12 [00:00<?, ? Segments/s]
# Overall Progress:  74% 2434/3292 [01:03<00:17, 49.41 Computational Sequence Entries/s]
#   0% 0/4 [00:00<?, ? Segments/s]
# Aligning gLdRUsLw4CA:   0% 0/4 [00:00<?, ? Segments/s]
#
#   0% 0/10 [00:00<?, ? Segments/s]
# Aligning gPWyANEm0eE:   0% 0/10 [00:00<?, ? Segments/s]
#
#   0% 0/9 [00:00<?, ? Segments/s]
# Aligning gR3igiwaeyc:   0% 0/9 [00:00<?, ? Segments/s]
#
#   0% 0/17 [00:00<?, ? Segments/s]
# Aligning gR4gM_WXesQ:   0% 0/17 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning gRAmIaSlm80:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/7 [00:00<?, ? Segments/s]
# Aligning gU7McujYYPY:   0% 0/7 [00:00<?, ? Segments/s]
# Overall Progress:  74% 2440/3292 [01:03<00:18, 44.98 Computational Sequence Entries/s]
#   0% 0/6 [00:00<?, ? Segments/s]
# Aligning gVqs4TzqySw:   0% 0/6 [00:00<?, ? Segments/s]
#
#   0% 0/11 [00:00<?, ? Segments/s]
# Aligning gXDRWhJbfFU:   0% 0/11 [00:00<?, ? Segments/s]
#
#   0% 0/20 [00:00<?, ? Segments/s]
# Aligning gXuiIWRxrw4:   0% 0/20 [00:00<?, ? Segments/s]
#
#   0% 0/15 [00:00<?, ? Segments/s]
# Aligning gZDyk95Xob4:   0% 0/15 [00:00<?, ? Segments/s]
#
#   0% 0/11 [00:00<?, ? Segments/s]
# Aligning gZF-YNQHqwI:   0% 0/11 [00:00<?, ? Segments/s]
# Overall Progress:  74% 2445/3292 [01:03<00:24, 35.15 Computational Sequence Entries/s]
#   0% 0/24 [00:00<?, ? Segments/s]
# Aligning gcFECfN4BCU:   0% 0/24 [00:00<?, ? Segments/s]
#
#   0% 0/4 [00:00<?, ? Segments/s]
# Aligning gcGZp9JX_qE:   0% 0/4 [00:00<?, ? Segments/s]
#
#   0% 0/6 [00:00<?, ? Segments/s]
# Aligning gcpsSao7kHM:   0% 0/6 [00:00<?, ? Segments/s]
#
#   0% 0/9 [00:00<?, ? Segments/s]
# Aligning ge071m9bGeY:   0% 0/9 [00:00<?, ? Segments/s]
# Overall Progress:  74% 2449/3292 [01:03<00:24, 34.83 Computational Sequence Entries/s]
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning gfHrSg3BwiQ:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning ggbV7YeSl7k:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/29 [00:00<?, ? Segments/s]
# Aligning gjEYmdWrBLM:   0% 0/29 [00:00<?, ? Segments/s]
#
#   0% 0/6 [00:00<?, ? Segments/s]
# Aligning gjGL6YY6oMs:   0% 0/6 [00:00<?, ? Segments/s]
# Overall Progress:  75% 2453/3292 [01:03<00:24, 34.25 Computational Sequence Entries/s]
#   0% 0/8 [00:00<?, ? Segments/s]
# Aligning gjSyl6evrWk:   0% 0/8 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning gm4l099casQ:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/4 [00:00<?, ? Segments/s]
# Aligning goMtnNHQ_z4:   0% 0/4 [00:00<?, ? Segments/s]
#
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning gpn71-aKWwQ:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning gr8mzv2xZ2s:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning gr9YU-UTJzQ:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/5 [00:00<?, ? Segments/s]
# Aligning grePRQ8zonA:   0% 0/5 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning grsV1YN1z5s:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/4 [00:00<?, ? Segments/s]
# Aligning guRD0zQC6Q0:   0% 0/4 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning gv43BPYYxKQ:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/4 [00:00<?, ? Segments/s]
# Aligning gvjQ1XfMA_g:   0% 0/4 [00:00<?, ? Segments/s]
# Overall Progress:  75% 2464/3292 [01:03<00:16, 50.81 Computational Sequence Entries/s]
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning gvrfI9e5xHQ:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning gzZ8NTeTzRs:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/22 [00:00<?, ? Segments/s]
# Aligning h1ZZHUU4j0k:   0% 0/22 [00:00<?, ? Segments/s]
#
#   0% 0/4 [00:00<?, ? Segments/s]
# Aligning h4LrwMn94ss:   0% 0/4 [00:00<?, ? Segments/s]
#
#   0% 0/29 [00:00<?, ? Segments/s]
# Aligning h7p5URoookk:   0% 0/29 [00:00<?, ? Segments/s]
#
#   0% 0/9 [00:00<?, ? Segments/s]
# Aligning hASTLbFHrEs:   0% 0/9 [00:00<?, ? Segments/s]
# Overall Progress:  75% 2470/3292 [01:04<00:18, 44.67 Computational Sequence Entries/s]
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning hBzw4r0kfjA:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/9 [00:00<?, ? Segments/s]
# Aligning hCFV5VLgS0A:   0% 0/9 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning hE-sA5umuCk:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/8 [00:00<?, ? Segments/s]
# Aligning hF6kFQPdBjY:   0% 0/8 [00:00<?, ? Segments/s]
#
#   0% 0/9 [00:00<?, ? Segments/s]
# Aligning hGRRlXfH0BY:   0% 0/9 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning hI7ObFqn9Bg:   0% 0/1 [00:00<?, ? Segments/s]
# Overall Progress:  75% 2476/3292 [01:04<00:16, 48.06 Computational Sequence Entries/s]
#   0% 0/5 [00:00<?, ? Segments/s]
# Aligning hIQhkTjNaQc:   0% 0/5 [00:00<?, ? Segments/s]
#
#   0% 0/5 [00:00<?, ? Segments/s]
# Aligning hOp6I4jGvu4:   0% 0/5 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning hSEfYcIjIr4:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/8 [00:00<?, ? Segments/s]
# Aligning hSgKOKK3L8M:   0% 0/8 [00:00<?, ? Segments/s]
#
#   0% 0/3 [00:00<?, ? Segments/s]
# Aligning hThsntvCk2s:   0% 0/3 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning hUBQrLjm4M4:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/4 [00:00<?, ? Segments/s]
# Aligning hawztAtYHCE:   0% 0/4 [00:00<?, ? Segments/s]
#
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning hbJfSyJKBEA:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/2 [00:00<?, ? Segments/s]
# Aligning hdLC4Ro977Q:   0% 0/2 [00:00<?, ? Segments/s]
#
#   0% 0/12 [00:00<?, ? Segments/s]
# Aligning he475nnmMi0:   0% 0/12 [00:00<?, ? Segments/s]
# Overall Progress:  76% 2486/3292 [01:04<00:14, 55.87 Computational Sequence Entries/s]
#   0% 0/1 [00:00<?, ? Segments/s]
# Aligning hfK8QtTd7fo:   0% 0/1 [00:00<?, ? Segments/s]
#
#   0% 0/9 [00:00<?, ? Segments/s]
# Aligning hfVXx8hfKak:   0% 0/9 [00:00<?, ? Segments/s]
#
#   0% 0/8 [00:00<?, ? Segments/s]
# Aligning hfvmQuhqMmY:   0% 0/8 [00:00<?, ? Segments/s]
#
#   0% 0/3 [00:00<?, ? Segments/s]
# ...
# 2025-08-15 00:18:47 - src.training.trainer - INFO - Epoch 41 - Validation loss: 0.0123
# 2025-08-15 00:18:47,187 - src.training.metrics - INFO - Epoch 41 - Val metrics:
# 2025-08-15 00:18:47 - src.training.metrics - INFO - Epoch 41 - Val metrics:
# 2025-08-15 00:18:47 - src.training.metrics - INFO - Epoch 41 - Val metrics:
# 2025-08-15 00:18:47,187 - src.training.metrics - INFO -   MAE: 0.0866
# 2025-08-15 00:18:47 - src.training.metrics - INFO -   MAE: 0.0866
# 2025-08-15 00:18:47 - src.training.metrics - INFO -   MAE: 0.0866
# 2025-08-15 00:18:47,187 - src.training.metrics - INFO -   Correlation: 0.5401
# 2025-08-15 00:18:47 - src.training.metrics - INFO -   Correlation: 0.5401
# 2025-08-15 00:18:47 - src.training.metrics - INFO -   Correlation: 0.5401
# 2025-08-15 00:18:47,187 - src.training.metrics - INFO -   Binary Accuracy: 0.9583
# 2025-08-15 00:18:47 - src.training.metrics - INFO -   Binary Accuracy: 0.9583
# 2025-08-15 00:18:47 - src.training.metrics - INFO -   Binary Accuracy: 0.9583
# 2025-08-15 00:18:47,187 - src.training.metrics - INFO -   Binary F1: 0.9786
# 2025-08-15 00:18:47 - src.training.metrics - INFO -   Binary F1: 0.9786
# 2025-08-15 00:18:47 - src.training.metrics - INFO -   Binary F1: 0.9786
# 2025-08-15 00:18:47,187 - src.training.metrics - INFO -   7-class Accuracy: 0.9773
# 2025-08-15 00:18:47 - src.training.metrics - INFO -   7-class Accuracy: 0.9773
# 2025-08-15 00:18:47 - src.training.metrics - INFO -   7-class Accuracy: 0.9773
# 2025-08-15 00:18:47,187 - src.training.metrics - INFO -   7-class F1: 0.9689
# 2025-08-15 00:18:47 - src.training.metrics - INFO -   7-class F1: 0.9689
# 2025-08-15 00:18:47 - src.training.metrics - INFO -   7-class F1: 0.9689
# 2025-08-15 00:18:47,187 - src.training.trainer - INFO - No improvement for 7 evaluation steps.
# 2025-08-15 00:18:47 - src.training.trainer - INFO - No improvement for 7 evaluation steps.
# 2025-08-15 00:18:47 - src.training.trainer - INFO - No improvement for 7 evaluation steps.
# Epoch 42: 100% 19/19 [00:01<00:00, 10.59it/s, loss=0.0139]
# 2025-08-15 00:18:48,983 - src.training.trainer - INFO - Epoch 42 - Train loss: 0.0133
# 2025-08-15 00:18:48 - src.training.trainer - INFO - Epoch 42 - Train loss: 0.0133
# 2025-08-15 00:18:48 - src.training.trainer - INFO - Epoch 42 - Train loss: 0.0133
# 2025-08-15 00:18:52,011 - src.training.trainer - INFO - Epoch 42 - Validation loss: 0.0126
# 2025-08-15 00:18:52 - src.training.trainer - INFO - Epoch 42 - Validation loss: 0.0126
# 2025-08-15 00:18:52 - src.training.trainer - INFO - Epoch 42 - Validation loss: 0.0126
# 2025-08-15 00:18:52,012 - src.training.metrics - INFO - Epoch 42 - Val metrics:
# 2025-08-15 00:18:52 - src.training.metrics - INFO - Epoch 42 - Val metrics:
# 2025-08-15 00:18:52 - src.training.metrics - INFO - Epoch 42 - Val metrics:
# 2025-08-15 00:18:52,012 - src.training.metrics - INFO -   MAE: 0.0874
# 2025-08-15 00:18:52 - src.training.metrics - INFO -   MAE: 0.0874
# 2025-08-15 00:18:52 - src.training.metrics - INFO -   MAE: 0.0874
# 2025-08-15 00:18:52,012 - src.training.metrics - INFO -   Correlation: 0.5447
# 2025-08-15 00:18:52 - src.training.metrics - INFO -   Correlation: 0.5447
# 2025-08-15 00:18:52 - src.training.metrics - INFO -   Correlation: 0.5447
# 2025-08-15 00:18:52,012 - src.training.metrics - INFO -   Binary Accuracy: 0.9583
# 2025-08-15 00:18:52 - src.training.metrics - INFO -   Binary Accuracy: 0.9583
# 2025-08-15 00:18:52 - src.training.metrics - INFO -   Binary Accuracy: 0.9583
# 2025-08-15 00:18:52,012 - src.training.metrics - INFO -   Binary F1: 0.9786
# 2025-08-15 00:18:52 - src.training.metrics - INFO -   Binary F1: 0.9786
# 2025-08-15 00:18:52 - src.training.metrics - INFO -   Binary F1: 0.9786
# 2025-08-15 00:18:52,012 - src.training.metrics - INFO -   7-class Accuracy: 0.9811
# 2025-08-15 00:18:52 - src.training.metrics - INFO -   7-class Accuracy: 0.9811
# 2025-08-15 00:18:52 - src.training.metrics - INFO -   7-class Accuracy: 0.9811
# 2025-08-15 00:18:52,012 - src.training.metrics - INFO -   7-class F1: 0.9759
# 2025-08-15 00:18:52 - src.training.metrics - INFO -   7-class F1: 0.9759
# 2025-08-15 00:18:52 - src.training.metrics - INFO -   7-class F1: 0.9759
# 2025-08-15 00:18:52,012 - src.training.trainer - INFO - No improvement for 8 evaluation steps.
# 2025-08-15 00:18:52 - src.training.trainer - INFO - No improvement for 8 evaluation steps.
# 2025-08-15 00:18:52 - src.training.trainer - INFO - No improvement for 8 evaluation steps.
# Epoch 43: 100% 19/19 [00:01<00:00, 10.70it/s, loss=0.0154]
# 2025-08-15 00:18:53,789 - src.training.trainer - INFO - Epoch 43 - Train loss: 0.0128
# 2025-08-15 00:18:53 - src.training.trainer - INFO - Epoch 43 - Train loss: 0.0128
# 2025-08-15 00:18:53 - src.training.trainer - INFO - Epoch 43 - Train loss: 0.0128
# 2025-08-15 00:18:56,798 - src.training.trainer - INFO - Epoch 43 - Validation loss: 0.0113
# 2025-08-15 00:18:56 - src.training.trainer - INFO - Epoch 43 - Validation loss: 0.0113
# 2025-08-15 00:18:56 - src.training.trainer - INFO - Epoch 43 - Validation loss: 0.0113
# 2025-08-15 00:18:56,799 - src.training.metrics - INFO - Epoch 43 - Val metrics:
# 2025-08-15 00:18:56 - src.training.metrics - INFO - Epoch 43 - Val metrics:
# 2025-08-15 00:18:56 - src.training.metrics - INFO - Epoch 43 - Val metrics:
# 2025-08-15 00:18:56,799 - src.training.metrics - INFO -   MAE: 0.0891
# 2025-08-15 00:18:56 - src.training.metrics - INFO -   MAE: 0.0891
# 2025-08-15 00:18:56 - src.training.metrics - INFO -   MAE: 0.0891
# 2025-08-15 00:18:56,799 - src.training.metrics - INFO -   Correlation: 0.5413
# 2025-08-15 00:18:56 - src.training.metrics - INFO -   Correlation: 0.5413
# 2025-08-15 00:18:56 - src.training.metrics - INFO -   Correlation: 0.5413
# 2025-08-15 00:18:56,799 - src.training.metrics - INFO -   Binary Accuracy: 0.9659
# 2025-08-15 00:18:56 - src.training.metrics - INFO -   Binary Accuracy: 0.9659
# 2025-08-15 00:18:56 - src.training.metrics - INFO -   Binary Accuracy: 0.9659
# 2025-08-15 00:18:56,799 - src.training.metrics - INFO -   Binary F1: 0.9827
# 2025-08-15 00:18:56 - src.training.metrics - INFO -   Binary F1: 0.9827
# 2025-08-15 00:18:56 - src.training.metrics - INFO -   Binary F1: 0.9827
# 2025-08-15 00:18:56,799 - src.training.metrics - INFO -   7-class Accuracy: 0.9773
# 2025-08-15 00:18:56 - src.training.metrics - INFO -   7-class Accuracy: 0.9773
# 2025-08-15 00:18:56 - src.training.metrics - INFO -   7-class Accuracy: 0.9773
# 2025-08-15 00:18:56,799 - src.training.metrics - INFO -   7-class F1: 0.9728
# 2025-08-15 00:18:56 - src.training.metrics - INFO -   7-class F1: 0.9728
# 2025-08-15 00:18:56 - src.training.metrics - INFO -   7-class F1: 0.9728
# 2025-08-15 00:18:56,799 - src.training.trainer - INFO - No improvement for 9 evaluation steps.
# 2025-08-15 00:18:56 - src.training.trainer - INFO - No improvement for 9 evaluation steps.
# 2025-08-15 00:18:56 - src.training.trainer - INFO - No improvement for 9 evaluation steps.
# Epoch 44: 100% 19/19 [00:01<00:00, 10.88it/s, loss=0.0109]
# 2025-08-15 00:18:58,547 - src.training.trainer - INFO - Epoch 44 - Train loss: 0.0131
# 2025-08-15 00:18:58 - src.training.trainer - INFO - Epoch 44 - Train loss: 0.0131
# 2025-08-15 00:18:58 - src.training.trainer - INFO - Epoch 44 - Train loss: 0.0131
# 2025-08-15 00:19:01,637 - src.training.trainer - INFO - Epoch 44 - Validation loss: 0.0118
# 2025-08-15 00:19:01 - src.training.trainer - INFO - Epoch 44 - Validation loss: 0.0118
# 2025-08-15 00:19:01 - src.training.trainer - INFO - Epoch 44 - Validation loss: 0.0118
# 2025-08-15 00:19:01,638 - src.training.metrics - INFO - Epoch 44 - Val metrics:
# 2025-08-15 00:19:01 - src.training.metrics - INFO - Epoch 44 - Val metrics:
# 2025-08-15 00:19:01 - src.training.metrics - INFO - Epoch 44 - Val metrics:
# 2025-08-15 00:19:01,638 - src.training.metrics - INFO -   MAE: 0.0869
# 2025-08-15 00:19:01 - src.training.metrics - INFO -   MAE: 0.0869
# 2025-08-15 00:19:01 - src.training.metrics - INFO -   MAE: 0.0869
# 2025-08-15 00:19:01,638 - src.training.metrics - INFO -   Correlation: 0.5408
# 2025-08-15 00:19:01 - src.training.metrics - INFO -   Correlation: 0.5408
# 2025-08-15 00:19:01 - src.training.metrics - INFO -   Correlation: 0.5408
# 2025-08-15 00:19:01,638 - src.training.metrics - INFO -   Binary Accuracy: 0.9583
# 2025-08-15 00:19:01 - src.training.metrics - INFO -   Binary Accuracy: 0.9583
# 2025-08-15 00:19:01 - src.training.metrics - INFO -   Binary Accuracy: 0.9583
# 2025-08-15 00:19:01,638 - src.training.metrics - INFO -   Binary F1: 0.9786
# 2025-08-15 00:19:01 - src.training.metrics - INFO -   Binary F1: 0.9786
# 2025-08-15 00:19:01 - src.training.metrics - INFO -   Binary F1: 0.9786
# 2025-08-15 00:19:01,638 - src.training.metrics - INFO -   7-class Accuracy: 0.9773
# 2025-08-15 00:19:01 - src.training.metrics - INFO -   7-class Accuracy: 0.9773
# 2025-08-15 00:19:01 - src.training.metrics - INFO -   7-class Accuracy: 0.9773
# 2025-08-15 00:19:01,638 - src.training.metrics - INFO -   7-class F1: 0.9728
# 2025-08-15 00:19:01 - src.training.metrics - INFO -   7-class F1: 0.9728
# 2025-08-15 00:19:01 - src.training.metrics - INFO -   7-class F1: 0.9728
# 2025-08-15 00:19:01,638 - src.training.trainer - INFO - No improvement for 10 evaluation steps.
# 2025-08-15 00:19:01 - src.training.trainer - INFO - No improvement for 10 evaluation steps.
# 2025-08-15 00:19:01 - src.training.trainer - INFO - No improvement for 10 evaluation steps.
# 2025-08-15 00:19:01,638 - src.training.trainer - INFO - Early stopping at epoch 44
# 2025-08-15 00:19:01 - src.training.trainer - INFO - Early stopping at epoch 44
# 2025-08-15 00:19:01 - src.training.trainer - INFO - Early stopping at epoch 44
# 2025-08-15 00:19:01,638 - src.training.trainer - INFO - Training completed. Best model found at epoch 34 with validation loss: 0.0109
# 2025-08-15 00:19:01 - src.training.trainer - INFO - Training completed. Best model found at epoch 34 with validation loss: 0.0109
# 2025-08-15 00:19:01 - src.training.trainer - INFO - Training completed. Best model found at epoch 34 with validation loss: 0.0109
# 2025-08-15 00:19:01,640 - root - INFO - Training completed in 218.68 seconds
# 2025-08-15 00:19:01 - root - INFO - Training completed in 218.68 seconds
# 2025-08-15 00:19:01 - root - INFO - Training completed in 218.68 seconds
# Figure saved to /content/nuu_multi-Multimodal-Sentiment-Analysis-with-MOSEI-Dataset/logs/multimodal_training_curves.png
# Figure(1000x400)
# 2025-08-15 00:19:02,119 - root - INFO - Evaluating on test set...
# 2025-08-15 00:19:02 - root - INFO - Evaluating on test set...
# 2025-08-15 00:19:02 - root - INFO - Evaluating on test set...
# 2025-08-15 00:19:02,119 - src.training.trainer - INFO - Evaluating model on test set...
# 2025-08-15 00:19:02 - src.training.trainer - INFO - Evaluating model on test set...
# 2025-08-15 00:19:02 - src.training.trainer - INFO - Evaluating model on test set...
# 2025-08-15 00:19:02,119 - src.training.trainer - INFO - Loading checkpoint from /content/nuu_multi-Multimodal-Sentiment-Analysis-with-MOSEI-Dataset/models/multimodal_fusion_best.pt
# 2025-08-15 00:19:02 - src.training.trainer - INFO - Loading checkpoint from /content/nuu_multi-Multimodal-Sentiment-Analysis-with-MOSEI-Dataset/models/multimodal_fusion_best.pt
# 2025-08-15 00:19:02 - src.training.trainer - INFO - Loading checkpoint from /content/nuu_multi-Multimodal-Sentiment-Analysis-with-MOSEI-Dataset/models/multimodal_fusion_best.pt
# 2025-08-15 00:19:02,237 - src.training.trainer - INFO - Loaded checkpoint with best validation loss: 0.0109
# 2025-08-15 00:19:02 - src.training.trainer - INFO - Loaded checkpoint with best validation loss: 0.0109
# 2025-08-15 00:19:02 - src.training.trainer - INFO - Loaded checkpoint with best validation loss: 0.0109
# 2025-08-15 00:19:03,783 - src.training.metrics - INFO - Test metrics:
# 2025-08-15 00:19:03 - src.training.metrics - INFO - Test metrics:
# 2025-08-15 00:19:03 - src.training.metrics - INFO - Test metrics:
# 2025-08-15 00:19:03,783 - src.training.metrics - INFO -   MAE: 0.0882
# 2025-08-15 00:19:03 - src.training.metrics - INFO -   MAE: 0.0882
# 2025-08-15 00:19:03 - src.training.metrics - INFO -   MAE: 0.0882
# 2025-08-15 00:19:03,784 - src.training.metrics - INFO -   Correlation: 0.5138
# 2025-08-15 00:19:03 - src.training.metrics - INFO -   Correlation: 0.5138
# 2025-08-15 00:19:03 - src.training.metrics - INFO -   Correlation: 0.5138
# 2025-08-15 00:19:03,784 - src.training.metrics - INFO -   Binary Accuracy: 0.9544
# 2025-08-15 00:19:03 - src.training.metrics - INFO -   Binary Accuracy: 0.9544
# 2025-08-15 00:19:03 - src.training.metrics - INFO -   Binary Accuracy: 0.9544
# 2025-08-15 00:19:03,784 - src.training.metrics - INFO -   Binary F1: 0.9767
# 2025-08-15 00:19:03 - src.training.metrics - INFO -   Binary F1: 0.9767
# 2025-08-15 00:19:03 - src.training.metrics - INFO -   Binary F1: 0.9767
# 2025-08-15 00:19:03,784 - src.training.metrics - INFO -   7-class Accuracy: 0.9772
# 2025-08-15 00:19:03 - src.training.metrics - INFO -   7-class Accuracy: 0.9772
# 2025-08-15 00:19:03 - src.training.metrics - INFO -   7-class Accuracy: 0.9772
# 2025-08-15 00:19:03,784 - src.training.metrics - INFO -   7-class F1: 0.9674
# 2025-08-15 00:19:03 - src.training.metrics - INFO -   7-class F1: 0.9674
# 2025-08-15 00:19:03 - src.training.metrics - INFO -   7-class F1: 0.9674
# 2025-08-15 00:19:03,784 - src.training.metrics - INFO - Test metrics:
# 2025-08-15 00:19:03 - src.training.metrics - INFO - Test metrics:
# 2025-08-15 00:19:03 - src.training.metrics - INFO - Test metrics:
# 2025-08-15 00:19:03,784 - src.training.metrics - INFO -   MAE: 0.0882
# 2025-08-15 00:19:03 - src.training.metrics - INFO -   MAE: 0.0882
# 2025-08-15 00:19:03 - src.training.metrics - INFO -   MAE: 0.0882
# 2025-08-15 00:19:03,784 - src.training.metrics - INFO -   Correlation: 0.5138
# 2025-08-15 00:19:03 - src.training.metrics - INFO -   Correlation: 0.5138
# 2025-08-15 00:19:03 - src.training.metrics - INFO -   Correlation: 0.5138
# 2025-08-15 00:19:03,784 - src.training.metrics - INFO -   Binary Accuracy: 0.9544
# 2025-08-15 00:19:03 - src.training.metrics - INFO -   Binary Accuracy: 0.9544
# 2025-08-15 00:19:03 - src.training.metrics - INFO -   Binary Accuracy: 0.9544
# 2025-08-15 00:19:03,784 - src.training.metrics - INFO -   Binary F1: 0.9767
# 2025-08-15 00:19:03 - src.training.metrics - INFO -   Binary F1: 0.9767
# 2025-08-15 00:19:03 - src.training.metrics - INFO -   Binary F1: 0.9767
# 2025-08-15 00:19:03,784 - src.training.metrics - INFO -   7-class Accuracy: 0.9772
# 2025-08-15 00:19:03 - src.training.metrics - INFO -   7-class Accuracy: 0.9772
# 2025-08-15 00:19:03 - src.training.metrics - INFO -   7-class Accuracy: 0.9772
# 2025-08-15 00:19:03,784 - src.training.metrics - INFO -   7-class F1: 0.9674
# 2025-08-15 00:19:03 - src.training.metrics - INFO -   7-class F1: 0.9674
# 2025-08-15 00:19:03 - src.training.metrics - INFO -   7-class F1: 0.9674
# Scatter plot saved to /content/nuu_multi-Multimodal-Sentiment-Analysis-with-MOSEI-Dataset/logs/multimodal_predictions.png
# Figure(800x800)
# 2025-08-15 00:19:05,904 - root - INFO - Training and evaluation completed!
# 2025-08-15 00:19:05 - root - INFO - Training and evaluation completed!
# 2025-08-15 00:19:05 - root - INFO - Training and evaluation completed!
#
# ===== Multimodal Sentiment Analysis Console =====
# 1. Download and preprocess dataset
# 2. Train a new model
# 3. Evaluate a trained model
# 4. Visualize training results
# 5. Exit
# =================================================
# Enter your choice (1-5): 3
#
# ===== Multimodal Sentiment Analysis Console =====
# 1. Download and preprocess dataset
# 2. Train a new model
# 3. Evaluate a trained model
# 4. Visualize training results
# 5. Exit
# =================================================
# Enter your choice (1-5): 4
#
# ===== Multimodal Sentiment Analysis Console =====
# 1. Download and preprocess dataset
# 2. Train a new model
# 3. Evaluate a trained model
# 4. Visualize training results
# 5. Exit
# =================================================
# Enter your choice (1-5): 5
# 2025-08-15 00:19:28,308 - __main__ - INFO - Exiting the console. Goodbye!
# 2025-08-15 00:19:28 - __main__ - INFO - Exiting the console. Goodbye!
# 2025-08-15 00:19:28 - __main__ - INFO - Exiting the console. Goodbye!

# %%
# !python inference.py
# Out:
# 2025-08-15 00:19:41.308305: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-15 00:19:41.327331: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755217181.349276   14649 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755217181.355833   14649 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1755217181.373285   14649 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755217181.373324   14649 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755217181.373328   14649 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755217181.373334   14649 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-08-15 00:19:41.378318: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/moviepy/video/io/sliders.py:61: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if event.key is 'enter':
#
# error: XDG_RUNTIME_DIR not set in the environment.
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# Enter the path to your trained model checkpoint (.pt): /content/nuu_multi-Multimodal-Sentiment-Analysis-with-MOSEI-Dataset/models/multimodal_fusion_best.pt
# Enter the path to the directory containing your .mp4 files: /content
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/torch/nn/modules/transformer.py:385: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
#
# tokenizer_config.json: 100% 49.0/49.0 [00:00<00:00, 388kB/s]
# vocab.txt: 100% 996k/996k [00:00<00:00, 14.4MB/s]
# tokenizer.json: 100% 1.96M/1.96M [00:00<00:00, 28.3MB/s]
# config.json: 100% 625/625 [00:00<00:00, 4.42MB/s]
# model.safetensors: 100% 714M/714M [00:02<00:00, 339MB/s]
# Processing Videos:   0% 0/4 [00:00<?, ?it/s]
# config.json: 1.98kB [00:00, 8.21MB/s]
#
# model.safetensors:   0% 0.00/290M [00:00<?, ?B/s]
# model.safetensors:   1% 1.96M/290M [00:00<02:09, 2.23MB/s]
# model.safetensors:   9% 25.5M/290M [00:01<00:08, 30.4MB/s]
# model.safetensors:  37% 109M/290M [00:01<00:01, 137MB/s]
# model.safetensors: 100% 290M/290M [00:01<00:00, 204MB/s]
#
# generation_config.json: 3.81kB [00:00, 18.3MB/s]
#
# tokenizer_config.json: 283kB [00:00, 284MB/s]
#
# vocab.json: 836kB [00:00, 129MB/s]
#
# tokenizer.json: 2.48MB [00:00, 170MB/s]
#
# merges.txt: 494kB [00:00, 119MB/s]
#
# normalizer.json: 52.7kB [00:00, 104MB/s]
#
# added_tokens.json: 34.6kB [00:00, 98.6MB/s]
#
# special_tokens_map.json: 2.19kB [00:00, 10.6MB/s]
#
# preprocessor_config.json: 185kB [00:00, 253MB/s]
# Device set to use cuda
# `return_token_timestamps` is deprecated for WhisperFeatureExtractor and will be removed in Transformers v5. Use `return_attention_mask` instead, as the number of frames can be inferred from it.
# Using custom `forced_decoder_ids` from the (generation) config. This is deprecated in favor of the `task` and `language` flags/config options.
# Transcription using a multilingual Whisper will default to language detection followed by transcription instead of translation to English. This might be a breaking change for your use case. If you want to instead always translate your audio to English, make sure to pass `language='en'`. See https://github.com/huggingface/transformers/pull/28687 for more details.
# Processing Videos:  25% 1/4 [00:10<00:30, 10.04s/it]Device set to use cuda
# Processing Videos:  50% 2/4 [00:11<00:09,  4.97s/it]Device set to use cuda
# Processing Videos:  75% 3/4 [00:12<00:03,  3.33s/it]Device set to use cuda
# Processing Videos: 100% 4/4 [00:14<00:00,  3.55s/it]

# %%
import pandas as pd
pd.read_csv('/content/predictions.csv')
# Out:
#                        ID     Label
# 0  validate_video_001.mp4  0.460210
# 1  validate_video_004.mp4  0.322754
# 2  validate_video_002.mp4  0.366591
# 3  validate_video_003.mp4  0.354779

# %% [markdown]
# sdsd

# %%
# %%writefile preprocess_v2.py
# preprocess_v2.py
import pandas as pd
from pathlib import Path
import logging
from sklearn.model_selection import train_test_split

logging.basicConfig(level=logging.INFO, format="%(asctime)s [%(levelname)s] %(message)s")

# Define the paths to your datasets (adjust if necessary)
CH_SIMS_PATH = Path("/root/.cache/kagglehub/competitions/msa-challenge-at-the-4th-pazhou-ai-competition/CH-SIMSv2/ch-simsv2s/meta.csv")
CMU_MOSEI_PATH = Path("/root/.cache/kagglehub/datasets/paulnkamau/dataset-msa-translations-complete/versions/1/CMU_Mosei_English/cmu_mosei_bilingual_en_zh.csv")
OUTPUT_DIR = Path("./processed_data_v2")
OUTPUT_DIR.mkdir(exist_ok=True)

# Define label mappings
LABEL_MAP_STR_TO_INT = {'SNEG': 0, 'WNEG': 1, 'NEUT': 2, 'WPOS': 3, 'SPOS': 4}

def map_ch_sims_label(score):
    if score in [-1.0, -0.8]: return 'SNEG'
    if score in [-0.6, -0.4, -0.2]: return 'WNEG'
    if score == 0.0: return 'NEUT'
    if score in [0.2, 0.4, 0.6]: return 'WPOS'
    if score in [0.8, 1.0]: return 'SPOS'
    return None

def process_ch_sims():
    logging.info(f"Processing CH-SIMS v2 from {CH_SIMS_PATH}...")
    df = pd.read_csv(CH_SIMS_PATH)
    df = df[['text', 'label', 'mode']].copy()
    df.rename(columns={'mode': 'split'}, inplace=True)
    df['label_str'] = df['label'].apply(map_ch_sims_label)
    df['language'] = 'chinese'
    df = df.dropna(subset=['label_str'])
    return df[['text', 'label_str', 'language', 'split']]

def process_cmu_mosei():
    logging.info(f"Processing CMU-MOSEI from {CMU_MOSEI_PATH}...")
    df = pd.read_csv(CMU_MOSEI_PATH)
    # We use the corrected English text for consistency
    df = df[['original_english', 'Label', 'split']].copy()
    df.rename(columns={'original_english': 'text', 'Label': 'label_str'}, inplace=True)
    df['language'] = 'english'
    df = df.dropna(subset=['text', 'label_str'])
    # The split column might contain 'valid', let's standardize it to 'val'
    df['split'] = df['split'].replace('valid', 'val')
    return df

def run():
    df_ch = process_ch_sims()
    df_mosei = process_cmu_mosei()

    df_combined = pd.concat([df_ch, df_mosei], ignore_index=True)
    df_combined = df_combined.sample(frac=1, random_state=42).reset_index(drop=True) # Shuffle

    # Apply the final integer mapping
    df_combined['label'] = df_combined['label_str'].map(LABEL_MAP_STR_TO_INT)

    # Ensure correct types
    df_combined = df_combined.dropna(subset=['label'])
    df_combined['label'] = df_combined['label'].astype(int)

    output_path = OUTPUT_DIR / "finetuning_data.csv"
    df_combined.to_csv(output_path, index=False)
    logging.info(f"Unified dataset created with {len(df_combined)} samples.")
    logging.info(f"Saved to {output_path}")
    logging.info("\nValue counts for labels:\n" + str(df_combined['label_str'].value_counts()))
    logging.info("\nValue counts for splits:\n" + str(df_combined['split'].value_counts()))

if __name__ == '__main__':
    run()
# Out:
# Writing preprocess_v2.py

# %%
# %%writefile main_v2.py
# main_v2.py
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from transformers import AutoTokenizer, AutoModel
from functools import partial

# Import our new V2 modules
import preprocess_v2
from src.data.dataset_v2 import FinetuneDataset, collate_fn
from src.models.fusion_v2 import MultilingualSentimentClassifier
from src.training.trainer_v2 import TrainerV2
from config import HIDDEN_DIM

def run_finetuning():
    # --- Config ---
    MODEL_NAME = "google-bert/bert-base-multilingual-cased"
    NUM_EPOCHS = 50
    LEARNING_RATE = 2e-5
    BATCH_SIZE = 64
    DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

    print(f"Using device: {DEVICE}")

    # --- 1. Load Tokenizer and Pre-trained BERT ---
    print(f"Loading tokenizer and model for '{MODEL_NAME}'...")
    tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
    bert_model = AutoModel.from_pretrained(MODEL_NAME)

    # --- 2. Create Datasets and DataLoaders ---
    print("Creating datasets...")
    train_dataset = FinetuneDataset(split='train')
    val_dataset = FinetuneDataset(split='val')

    # Use a partial function to pass the tokenizer to the collate_fn
    collate_with_tokenizer = partial(collate_fn, tokenizer=tokenizer)

    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, collate_fn=collate_with_tokenizer)
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, collate_fn=collate_with_tokenizer)

    # --- 3. Initialize Model ---
    print("Initializing classification model...")
    model = MultilingualSentimentClassifier(bert_model, hidden_dim=HIDDEN_DIM, num_classes=5)
    model.to(DEVICE)

    # --- 4. Setup Optimizer and Loss ---
    optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE)
    criterion = nn.CrossEntropyLoss()

    # --- 5. Train ---
    trainer = TrainerV2(model, optimizer, criterion, DEVICE, train_loader, val_loader)
    print("Starting fine-tuning...")
    trainer.train(num_epochs=NUM_EPOCHS)

    # --- 6. Save Model ---
    torch.save(model.state_dict(), './models/finetuned_multilingual_v2.pt')
    print("Fine-tuning complete. Model saved to './models/finetuned_multilingual_v2.pt'")

def main():
    print("--- Multilingual Fine-tuning Pipeline V2 ---")
    print("1. Preprocess and unify datasets")
    print("2. Run fine-tuning on the unified dataset")
    choice = input("Enter your choice (1-2): ").strip()

    if choice == '1':
        preprocess_v2.run()
    elif choice == '2':
        run_finetuning()
    else:
        print("Invalid choice.")

if __name__ == "__main__":
    main()
# Out:
# Overwriting main_v2.py

# %%
# !python preprocess_v2.py
# Out:
# 2025-08-15 01:05:31,604 [INFO] Processing CH-SIMS v2 from /root/.cache/kagglehub/competitions/msa-challenge-at-the-4th-pazhou-ai-competition/CH-SIMSv2/ch-simsv2s/meta.csv...
# 2025-08-15 01:05:31,625 [INFO] Processing CMU-MOSEI from /root/.cache/kagglehub/datasets/paulnkamau/dataset-msa-translations-complete/versions/1/CMU_Mosei_English/cmu_mosei_bilingual_en_zh.csv...
# 2025-08-15 01:05:32,085 [INFO] Unified dataset created with 27262 samples.
# 2025-08-15 01:05:32,085 [INFO] Saved to processed_data_v2/finetuning_data.csv
# 2025-08-15 01:05:32,088 [INFO]
# Value counts for labels:
# label_str
# NEUT    10075
# WPOS     7941
# WNEG     4618
# SNEG     2565
# SPOS     2063
# Name: count, dtype: int64
# 2025-08-15 01:05:32,090 [INFO]
# Value counts for splits:
# split
# train    19049
# test      5695
# val       1871
# valid      647
# Name: count, dtype: int64

# %%
# !python main_v2.py
# Out:
# --- Multilingual Fine-tuning Pipeline V2 ---
# 1. Preprocess and unify datasets
# 2. Run fine-tuning on the unified dataset
# Enter your choice (1-2): 2
# Using device: cuda
# Loading tokenizer and model for 'google-bert/bert-base-multilingual-cased'...
# tokenizer_config.json: 100% 49.0/49.0 [00:00<00:00, 435kB/s]
# config.json: 100% 625/625 [00:00<00:00, 5.22MB/s]
# vocab.txt: 996kB [00:00, 19.2MB/s]
# tokenizer.json: 1.96MB [00:00, 116MB/s]
# 2025-08-15 01:05:50.950973: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-15 01:05:50.971025: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755219950.989744   27744 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755219950.995215   27744 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1755219951.010358   27744 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755219951.010387   27744 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755219951.010390   27744 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755219951.010393   27744 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-08-15 01:05:51.014746: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# model.safetensors: 100% 714M/714M [00:02<00:00, 244MB/s]
# Creating datasets...
# Initializing classification model...
# Starting fine-tuning...
# Training: 100% 298/298 [00:59<00:00,  5.03it/s]
# Validating: 100% 30/30 [00:02<00:00, 13.03it/s]
# Epoch 1/50 | Train Loss: 1.2279 | Val Loss: 1.0636 | Val Acc: 0.5420 | Val F1: 0.5133
# Training: 100% 298/298 [00:59<00:00,  4.99it/s]
# Validating: 100% 30/30 [00:02<00:00, 13.05it/s]
# Epoch 2/50 | Train Loss: 1.0842 | Val Loss: 1.0560 | Val Acc: 0.5195 | Val F1: 0.5002
# Training: 100% 298/298 [00:59<00:00,  4.97it/s]
# Validating: 100% 30/30 [00:02<00:00, 13.07it/s]
# Epoch 3/50 | Train Loss: 0.9721 | Val Loss: 1.0831 | Val Acc: 0.5307 | Val F1: 0.5193
# Training: 100% 298/298 [00:59<00:00,  5.01it/s]
# Validating: 100% 30/30 [00:02<00:00, 12.98it/s]
# Epoch 4/50 | Train Loss: 0.8293 | Val Loss: 1.1819 | Val Acc: 0.5371 | Val F1: 0.5206
# Training: 100% 298/298 [00:59<00:00,  5.05it/s]
# Validating: 100% 30/30 [00:02<00:00, 13.03it/s]
# Epoch 5/50 | Train Loss: 0.6910 | Val Loss: 1.2684 | Val Acc: 0.5265 | Val F1: 0.5142
# Training: 100% 298/298 [00:59<00:00,  5.02it/s]
# Validating: 100% 30/30 [00:02<00:00, 13.02it/s]
# Epoch 6/50 | Train Loss: 0.5509 | Val Loss: 1.4605 | Val Acc: 0.5104 | Val F1: 0.5046
# Training:  81% 242/298 [00:48<00:11,  4.74it/s]

# %%
# %%writefile inference_dual.py
# inference_dual.py
import os
import sys
import logging
from pathlib import Path
import torch
import pandas as pd
from tqdm import tqdm
from transformers import AutoTokenizer, AutoModel, pipeline
from moviepy.editor import VideoFileClip

# Add project root to path for our model imports
sys.path.append(str(Path(__file__).resolve().parent))

# Import BOTH model architectures
from src.models.fusion import TransformerFusionModel as ModelV1
from src.models.fusion_v2 import MultilingualSentimentClassifier as ModelV2
from config import (
    TEXT_EMBEDDING_DIM, HIDDEN_DIM, NUM_ATTENTION_HEADS,
    NUM_TRANSFORMER_LAYERS, DROPOUT_RATE
)

# Setup logging
logging.basicConfig(level=logging.INFO, format="%(asctime)s [%(levelname)s] %(message)s")
logger = logging.getLogger(__name__)

# --- Constants and Mappings ---
LABEL_INT_TO_STR_V2 = {0: 'SNEG', 1: 'WNEG', 2: 'NEUT', 3: 'WPOS', 4: 'SPOS'}

def score_to_class_v1(score):
    """Converts a V1 regression score to a V2 class string."""
    if -3.0 <= score <= -2.0: return 'SNEG'
    if -2.0 < score <= -0.5: return 'WNEG'
    if -0.5 < score < 0.5: return 'NEUT'
    if 0.5 <= score < 2.0: return 'WPOS'
    if 2.0 <= score <= 3.0: return 'SPOS'
    return 'NEUT' # Default case

# --- Helper Functions (adapted for dual use) ---

def extract_audio_from_video(video_path, audio_output_path):
    # (This function is identical to the previous version)
    try:
        video_clip = VideoFileClip(str(video_path))
        audio_clip = video_clip.audio
        if audio_clip is None: return False
        audio_clip.write_audiofile(str(audio_output_path), codec='pcm_s16le', logger=None)
        video_clip.close()
        return True
    except Exception: return False

def get_transcript_and_language(audio_path, device):
    """Generates transcript and detects language using Whisper."""
    try:
        pipe = pipeline("automatic-speech-recognition", model="openai/whisper-base", device=device)
        # The 'return_timestamps' flag can provide more metadata, including language
        result = pipe(str(audio_path), generate_kwargs={"language": None}, return_timestamps=False)
        transcript = result['text'].strip()

        # Whisper's pipeline doesn't directly expose language in the simple output,
        # but we can infer it. For simplicity, we'll check for Chinese characters.
        # A more robust solution would involve a dedicated language detection library.
        language = 'chinese' if any('\u4e00' <= char <= '\u9fff' for char in transcript) else 'english'

        logger.info(f"Detected Language: {language} | Transcript: '{transcript[:50]}...'")
        return transcript, language
    except Exception as e:
        logger.error(f"Failed to transcribe audio {audio_path}: {e}")
        return "", "unknown"

def get_text_embedding(text, tokenizer, bert_model, device):
    # (This function is identical to the previous version)
    try:
        inputs = tokenizer(text, padding="max_length", truncation=True, max_length=512, return_tensors="pt")
        inputs = {key: val.to(device) for key, val in inputs.items()}
        with torch.no_grad():
            outputs = bert_model(**inputs)
            embedding = outputs.last_hidden_state
        return embedding
    except Exception: return torch.zeros(1, 512, TEXT_EMBEDDING_DIM)

# --- Main Inference Logic ---

def run_dual_inference():
    """
    Main function to run hybrid inference using both V1 and V2 models.
    """
    # 1. Get user input
    model_v1_path_str = input("Enter path to your ORIGINAL regression model (V1, .pt): ").strip()
    model_v2_path_str = input("Enter path to your FINETUNED classification model (V2, .pt): ").strip()
    video_dir_str = input("Enter path to the directory with your .mp4 files: ").strip()

    model_v1_path = Path(model_v1_path_str)
    model_v2_path = Path(model_v2_path_str)
    video_dir = Path(video_dir_str)

    # Validate paths
    if not model_v1_path.exists() or not model_v2_path.exists() or not video_dir.is_dir():
        logger.error("One or more paths are invalid. Please check and try again.")
        return

    # 2. Setup Device and Feature Extractor
    DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
    logger.info(f"Using device: {DEVICE}")

    logger.info("Loading Multilingual BERT for feature extraction...")
    bert_model_name = "bert-base-multilingual-cased"
    tokenizer = AutoTokenizer.from_pretrained(bert_model_name)
    feature_extractor_bert = AutoModel.from_pretrained(bert_model_name).to(DEVICE)
    feature_extractor_bert.eval()

    # 3. Load Models
    logger.info("Loading Model V1 (Regression)...")
    model_v1 = ModelV1(
        text_dim=TEXT_EMBEDDING_DIM, audio_dim=0, visual_dim=0, hidden_dim=HIDDEN_DIM,
        num_layers=NUM_TRANSFORMER_LAYERS, num_heads=NUM_ATTENTION_HEADS, dropout_rate=DROPOUT_RATE
    )

    logger.warning("Skipping V1 model loading due to embedding mismatch. Proceeding with V2-only logic.")

    logger.info("Loading Model V2 (Classification)...")
    # First, create the model structure with the base BERT
    model_v2_structure = ModelV2(feature_extractor_bert, hidden_dim=HIDDEN_DIM, num_classes=5)
    # Then, load the fine-tuned weights
    model_v2_structure.load_state_dict(torch.load(model_v2_path, map_location=DEVICE))
    model_v2 = model_v2_structure.to(DEVICE)
    model_v2.eval()
    logger.info("Models loaded successfully.")

    # 4. Process each video file
    video_files = list(video_dir.glob("*.mp4"))
    predictions_data = []
    temp_dir = Path("./temp_audio_dual")
    temp_dir.mkdir(exist_ok=True)

    for video_path in tqdm(video_files, desc="Processing Videos"):
        video_id = video_path.stem
        temp_audio_path = temp_dir / f"{video_id}.wav"

        if not extract_audio_from_video(video_path, temp_audio_path):
            continue

        transcript, language = get_transcript_and_language(temp_audio_path, DEVICE)
        if not transcript:
            os.remove(temp_audio_path)
            continue

        # Prepare input for V2 model (tokenizer is part of the V2 pipeline)
        inputs = tokenizer(transcript, padding=True, truncation=True, max_length=512, return_tensors="pt")
        inputs = {k: v.to(DEVICE) for k, v in inputs.items()}

        # Get V2 Prediction
        with torch.no_grad():
            logits = model_v2(**inputs)
            prediction_idx = torch.argmax(logits, dim=1).item()
            final_prediction_label = LABEL_INT_TO_STR_V2[prediction_idx]

        logger.info(f"Video: {video_path.name}, Language: {language}, Final Prediction: {final_prediction_label}")
        predictions_data.append({"ID": video_path.name, "Label": final_prediction_label})

        os.remove(temp_audio_path)

    # 5. Save results to CSV
    if predictions_data:
        df = pd.DataFrame(predictions_data)
        output_csv_path = video_dir / "predictions_dual.csv"
        df.to_csv(output_csv_path, index=False)
        logger.info(f"Inference complete! Predictions saved to {output_csv_path}")

    # Clean up temp directory
    temp_dir.rmdir()


if __name__ == "__main__":

    run_dual_inference()
# Out:
# Overwriting inference_dual.py

# %%
# !python inference_dual.py
# Out:
# 2025-08-15 01:00:12.686643: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-15 01:00:12.706341: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755219612.728502   25804 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755219612.735227   25804 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1755219612.753289   25804 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755219612.753322   25804 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755219612.753325   25804 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755219612.753328   25804 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-08-15 01:00:12.758337: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# error: XDG_RUNTIME_DIR not set in the environment.
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# Enter path to your ORIGINAL regression model (V1, .pt): /content/nuu_multi-Multimodal-Sentiment-Analysis-with-MOSEI-Dataset/models/multimodal_fusion_best.pt
# Enter path to your FINETUNED classification model (V2, .pt): /content/nuu_multi-Multimodal-Sentiment-Analysis-with-MOSEI-Dataset/models/finetuned_multilingual_v2.pt
# Enter path to the directory with your .mp4 files: /content
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/torch/nn/modules/transformer.py:385: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
#
# WARNING:__main__:Skipping V1 model loading due to embedding mismatch. Proceeding with V2-only logic.
# Processing Videos:   0% 0/4 [00:00<?, ?it/s]Device set to use cuda
# `return_token_timestamps` is deprecated for WhisperFeatureExtractor and will be removed in Transformers v5. Use `return_attention_mask` instead, as the number of frames can be inferred from it.
# Using custom `forced_decoder_ids` from the (generation) config. This is deprecated in favor of the `task` and `language` flags/config options.
# Transcription using a multilingual Whisper will default to language detection followed by transcription instead of translation to English. This might be a breaking change for your use case. If you want to instead always translate your audio to English, make sure to pass `language='en'`. See https://github.com/huggingface/transformers/pull/28687 for more details.
# Processing Videos:  25% 1/4 [00:03<00:10,  3.63s/it]Device set to use cuda
# Processing Videos:  50% 2/4 [00:04<00:04,  2.27s/it]Device set to use cuda
# Processing Videos:  75% 3/4 [00:06<00:01,  1.81s/it]Device set to use cuda
# Processing Videos: 100% 4/4 [00:07<00:00,  1.88s/it]

# %%
pd.read_csv('/content/predictions_dual.csv')
# Out:
#                        ID Label
# 0  validate_video_001.mp4  WPOS
# 1  validate_video_004.mp4  SPOS
# 2  validate_video_002.mp4  WNEG
# 3  validate_video_003.mp4  SNEG
